# %%
import pandas as pd
import datetime as dt
import numpy as np
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

monthly = pd.read_csv('../../../Dataset/Boulder_Monthly.csv')
monthly.drop(columns={'Unnamed: 0'}, inplace=True)
monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Energy__kWh_   55 non-null     float64
#  1   Month          55 non-null     object
#  2   Minimum T      55 non-null     int64
#  3   Maximum T      55 non-null     int64
#  4   Snow           55 non-null     float64
#  5   Precipitation  55 non-null     float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 2.7+ KB

# %%
# Define the columns we need to scale and we need to use for One-Hot Encoding
columns_to_scale = ['Energy__kWh_', 'Minimum T', 'Maximum T', 'Snow', 'Precipitation']
categorical_columns = ['Month']

# MinMax scaling for numerical columns and One-hot encoding for categorical columns
scaler = MinMaxScaler()
monthly_scaled = monthly.copy()
monthly_scaled[columns_to_scale] = scaler.fit_transform(monthly[columns_to_scale])

# One-hot encoding for categorical columns
onehot_encoder = OneHotEncoder(sparse=False)
categorical_encoded = onehot_encoder.fit_transform(monthly[categorical_columns])

# Get the feature names from the encoder
encoded_columns = []
for col, values in zip(categorical_columns, onehot_encoder.categories_):
    encoded_columns.extend([f'{col}_{value}' for value in values])

# Create DataFrame with encoded columns
categorical_encoded_df = pd.DataFrame(categorical_encoded, columns=encoded_columns)

# Concatenate the new encoded columns to the original DataFrame
monthly_scaled = pd.concat([monthly_scaled, categorical_encoded_df], axis=1)

# Drop the original categorical columns
monthly_scaled = monthly_scaled.drop(categorical_columns, axis=1)


# Split the dataset into training, validation, and testing sets
def split_dataset(df, train_ratio, val_ratio):

    total_size = len(df)
    train_size = int(train_ratio * total_size)
    val_size = int(val_ratio * total_size)
    test_size = total_size - train_size - val_size

    train_df = df[:train_size]
    val_df = df[train_size:train_size + val_size]
    test_df = df[train_size + val_size:]

    assert len(train_df) + len(val_df) + len(test_df) == total_size, "Dataset not split correctly."

    print(f'Training split ratio:   {round(len(train_df) / len(df), 3)}')
    print(f'Validation split ratio: {round(len(val_df) / len(df), 3)}')
    print(f'Testing split ratio:    {round(len(test_df) / len(df), 3)}')
    print("\nShapes of the datasets:")
    print(train_df.shape, val_df.shape, test_df.shape)

    return train_df, val_df, test_df

train_monthly_scaled, val_monthly_scaled, test_monthly_scaled = split_dataset(monthly_scaled, train_ratio=0.7, val_ratio=0.2)
# Out:
# Training split ratio:   0.691
# Validation split ratio: 0.2
# Testing split ratio:    0.109
#
# Shapes of the datasets:
# (38, 17) (11, 17) (6, 17)

# %%
# Reshape the data
def create_sequences(data, sequence_length):
    inputs = []
    targets = []
    for i in range(len(data) - sequence_length):
        sequence = data.iloc[i:i + sequence_length].values
        target = data.iloc[i + sequence_length]['Energy__kWh_']  # Predict the next value
        inputs.append(sequence)
        targets.append(target)

    inputs_array = np.array(inputs)
    targets_array = np.array(targets)
    
    print(f'Dataset split into sequences:')
    print(f'Sequences shape: {inputs_array.shape}')
    print(f'Targets shape: {targets_array.shape}\n')

    return np.array(inputs), np.array(targets)

sequence_length = 3
num_features = len(monthly_scaled.columns)

# Create the training, validation, and test data sequences
train_data_inputs, train_data_targets = create_sequences(train_monthly_scaled, sequence_length)
val_data_inputs, val_data_targets = create_sequences(val_monthly_scaled, sequence_length)
test_data_inputs, test_data_targets = create_sequences(test_monthly_scaled, sequence_length)
# Out:
# Dataset split into sequences:
# Sequences shape: (35, 3, 17)
# Targets shape: (35,)
#
# Dataset split into sequences:
# Sequences shape: (8, 3, 17)
# Targets shape: (8,)
#
# Dataset split into sequences:
# Sequences shape: (3, 3, 17)
# Targets shape: (3,)

# %%
# The input Datasets must have this input shape (-1, sequence_length, num_features)
train_data_inputs = train_data_inputs.reshape((-1, sequence_length, num_features))
val_data_inputs = val_data_inputs.reshape((-1, sequence_length, num_features))
test_data_inputs = test_data_inputs.reshape((-1, sequence_length, num_features))

train_data_inputs.shape, val_data_inputs.shape, test_data_inputs.shape
# Out:
# ((35, 3, 17), (8, 3, 17), (3, 3, 17))

# %%
class ScaledDotProductAttention(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(ScaledDotProductAttention, self).__init__(**kwargs)

    def call(self, queries, keys, values, mask):
        # Calculate the dot product of query and key matrices
        matmul_qk = tf.matmul(queries, keys, transpose_b=True) # Q * K.T

        # Get the dimension of the key matrix and cast to float32
        d_k = keys.shape[-1]
        d_k = tf.cast(d_k, tf.float32)

        # Scale the attention scores by the square root of the key dimension / Scoring the queries against the keys after transposing the latter, and scaling
        scaled_attention_scores = matmul_qk / tf.math.sqrt(d_k)

        # Apply the mask to the attention scores (if mask is provided)
        if mask is not None:
            scaled_attention_scores += (mask * -1e9)

        # Computing the weights by a softmax operation
        attention_weights = tf.nn.softmax(scaled_attention_scores, axis=-1)

        # Calculate the output by multiplying attention weights with value matrix
        output = tf.matmul(attention_weights, values)

        return output
    
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, h, d_k, d_v, d_model, **kwargs):
        super(MultiHeadAttention, self).__init__(**kwargs)
        self.h = h
        self.d_k = d_k
        self.d_v = d_v
        self.d_model = d_model

        # Initialize linear layers for projections
        self.query_projection = tf.keras.layers.Dense(units=(h * d_k), activation=None)
        self.key_projection = tf.keras.layers.Dense(units=(h * d_k), activation=None)
        self.value_projection = tf.keras.layers.Dense(units=(h * d_v), activation=None)

        # Initialize the final linear layer
        self.output_projection = tf.keras.layers.Dense(units=d_model, activation=None)

        # Initialize attention layer
        self.attention = ScaledDotProductAttention()

    def call(self, queries, keys, values, mask):
        batch_size = tf.shape(queries)[0]

        # Linear projections
        queries = tf.reshape(self.query_projection(queries), (batch_size, -1, self.h, self.d_k))
        keys = tf.reshape(self.key_projection(keys), (batch_size, -1, self.h, self.d_k))
        values = tf.reshape(self.value_projection(values), (batch_size, -1, self.h, self.d_v))

        # Transpose to have dimensions [batch_size, num_heads, seq_len, d_k/d_v]
        queries = tf.transpose(queries, perm=[0, 2, 1, 3])
        keys = tf.transpose(keys, perm=[0, 2, 1, 3])
        values = tf.transpose(values, perm=[0, 2, 1, 3])

        # Apply attention
        attention_output = self.attention(queries, keys, values, mask)

        # Transpose and concatenate to get the final output
        attention_output = tf.transpose(attention_output, perm=[0, 2, 1, 3])
        attention_output = tf.reshape(attention_output, (batch_size, -1, self.h * self.d_v))

        # Apply final linear layer
        output = self.output_projection(attention_output)

        return output
    

class PositionwiseFeedForward(tf.keras.layers.Layer):
    def __init__(self, d_model, d_ff, dropout_rate, **kwargs):
        super(PositionwiseFeedForward, self).__init__(**kwargs)

        # Feedforward neural network with a ReLU activation
        self.ffn = tf.keras.Sequential([tf.keras.layers.Dense(d_ff, activation='relu'),tf.keras.layers.Dense(d_model, activation=None)])

        # Dropout layer to prevent overfitting
        self.dropout = tf.keras.layers.Dropout(dropout_rate)

    def call(self, inputs):
        # Pass the inputs through the feedforward neural network
        ff_output = self.ffn(inputs)

        # Apply dropout to the output
        ff_output = self.dropout(ff_output)

        return ff_output

# %%
def Encoder(encoder_input, num_heads, d_ff, dropout_rate, encoder_mask):
    inputs = encoder_input
    
    # Extract the size of the model from the input shape
    d_model = inputs.shape[-1]

    # Multi-Head Self Attention
    attention_output = MultiHeadAttention(h=num_heads,
                                 d_k=d_model // num_heads,
                                 d_v=d_model // num_heads,
                                 d_model=d_model)(inputs, inputs, inputs, mask=encoder_mask)
    # Apply dropout for regularization
    attention_output = tf.keras.layers.Dropout(dropout_rate)(attention_output)

    # Add and Normalize step after Multi-Head Self Attention
    norm_attention_output = tf.keras.layers.LayerNormalization(epsilon=1e-6)(inputs + attention_output)

    # Feedforward Neural Network
    ffn = PositionwiseFeedForward(
        d_model=d_model,
        d_ff=d_ff,
        dropout_rate=dropout_rate
    )
    ff_output = ffn(norm_attention_output)
    # Apply dropout for regularization
    ff_output = tf.keras.layers.Dropout(dropout_rate)(ff_output)

    # Add and Normalize step after the Feedforward Neural Network
    encoder_output = tf.keras.layers.LayerNormalization(epsilon=1e-6)(norm_attention_output + ff_output)

    return encoder_output

# %%
def Decoder(inputs, encoder_output, num_heads, d_ff, dropout_rate, decoder_mask):
    inputs = inputs

    # Extract the size of the model from the input shape
    d_model = inputs.shape[-1]

    # Masked Self-Attention
    masked_attention_output = MultiHeadAttention(
                                                 h=num_heads,
                                                 d_k=d_model // num_heads,
                                                 d_v=d_model // num_heads,
                                                 d_model=d_model
                                                )(inputs, inputs, inputs, mask=decoder_mask)
    # Apply dropout for regularization
    masked_attention_output = tf.keras.layers.Dropout(dropout_rate)(masked_attention_output)

    # Add and Normalize the Masked Self-Attention output
    norm_masked_attention_output = tf.keras.layers.LayerNormalization(epsilon=1e-6)(masked_attention_output + inputs)

    # Cross-Attention with Encoder Output
    attention_output = MultiHeadAttention(
                                          h=num_heads,
                                          d_k=d_model // num_heads,
                                          d_v=d_model // num_heads,
                                          d_model=d_model
                                         )(norm_masked_attention_output, encoder_output, encoder_output, mask=decoder_mask)  # < ----- try and mask = mask
    # Apply dropout for regularization
    attention_output = tf.keras.layers.Dropout(dropout_rate)(attention_output)

    # Add and Normalize the Cross-Attention output
    attention_output = tf.keras.layers.LayerNormalization(epsilon=1e-6)(norm_masked_attention_output + attention_output)

    # Feedforward Neural Network
    ffn = PositionwiseFeedForward(
                                  d_model=d_model,
                                  d_ff=d_ff,
                                  dropout_rate=dropout_rate
                                 )
    ff_output = ffn(attention_output)
    # Apply dropout for regularization
    ff_output = tf.keras.layers.Dropout(dropout_rate)(ff_output)

    # Add and Normalize
    decoder_output = tf.keras.layers.LayerNormalization(epsilon=1e-6)(attention_output + ff_output)

    return decoder_output

# %%
def TransformerModel(input_shape, num_heads, d_ff, num_layers, dropout_rate, encoder_mask, decoder_mask):
    # Define the input layer
    inputs = tf.keras.layers.Input(shape=input_shape)

    # Encoder
    encoder = inputs
    for _ in range(num_layers):
        # Apply the Encoder function to the input for each layer
        encoder_output = Encoder(encoder, num_heads, d_ff, dropout_rate, encoder_mask)

    # Decoder
    decoder = encoder_output
    for _ in range(num_layers):
        # Apply the Decoder function to the encoder output for each layer
        decoder_output = Decoder(decoder, encoder, num_heads, d_ff, dropout_rate, decoder_mask)

    # Generate the final output with a TimeDistributed Dense layer
    pull_time_window = tf.keras.layers.GlobalAveragePooling1D(data_format='channels_first')(decoder_output)
    print("Shape of pull_time_window:", pull_time_window.shape)

    pull_time_window = tf.keras.layers.Dropout(0.1)(pull_time_window)
    outputs = tf.keras.layers.Dense(1, activation='linear')(pull_time_window)
    #outputs = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(units=1))(decoder_output)

    # Build the Keras model using the specified inputs and outputs
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    
    return model

# %%
def TransformerModel(input_shape, num_heads, d_ff, num_layers, dropout_rate, encoder_mask, decoder_mask):
    # Define the input layer
    inputs = tf.keras.layers.Input(shape=input_shape)

    # Encoder
    encoder = inputs
    for _ in range(num_layers):
        # Apply the Encoder function to the input for each layer
        encoder_output = Encoder(encoder, num_heads, d_ff, dropout_rate, encoder_mask)

    # Decoder
    decoder = encoder_output
    for _ in range(num_layers):
        # Apply the Decoder function to the encoder output for each layer
        decoder_output = Decoder(decoder, encoder, num_heads, d_ff, dropout_rate, decoder_mask)

    # Generate the final output with a TimeDistributed Dense layer
    pull_time_window = tf.keras.layers.GlobalAveragePooling1D(data_format='channels_first')(decoder_output)
    pull_time_window = tf.keras.layers.Dropout(0.1)(pull_time_window)
    outputs = tf.keras.layers.Dense(1, activation='linear')(pull_time_window)
    #outputs = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(units=1))(decoder_output)

    # Build the Keras model using the specified inputs and outputs
    model = keras.Model(inputs=inputs, outputs=outputs)
    
    return model

# %%
# Define the hyperparameters of the manual model
input_shape = (sequence_length, num_features)
num_heads = 1
d_ff = 64
num_layers = 3
dropout_rate = 0.1
encoder_mask = None
decoder_mask = tf.linalg.band_part(tf.ones((sequence_length, sequence_length)), -1, 0)  # Create a lower triangular mask
decoder_mask = 1 - decoder_mask  # Invert the mask

# Create the transformer model
manul_model = TransformerModel(input_shape, num_heads, d_ff, num_layers, dropout_rate, encoder_mask, decoder_mask)

manul_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 3, 17)]      0           []
#
#  multi_head_attention_56 (Multi  (None, None, 17)    1224        ['input_7[0][0]',
#  HeadAttention)                                                   'input_7[0][0]',
#                                                                   'input_7[0][0]']
#
#  dropout_138 (Dropout)          (None, None, 17)     0           ['multi_head_attention_56[0][0]']
#
#  tf.__operators__.add_94 (TFOpL  (None, 3, 17)       0           ['input_7[0][0]',
#  ambda)                                                           'dropout_138[0][0]']
#
#  layer_normalization_94 (LayerN  (None, 3, 17)       34          ['tf.__operators__.add_94[0][0]']
#  ormalization)
#
#  positionwise_feed_forward_38 (  (None, 3, 17)       2257        ['layer_normalization_94[0][0]']
#  PositionwiseFeedForward)
#
#  dropout_140 (Dropout)          (None, 3, 17)        0           ['positionwise_feed_forward_38[0]
#                                                                  [0]']
#
#  tf.__operators__.add_95 (TFOpL  (None, 3, 17)       0           ['layer_normalization_94[0][0]',
#  ambda)                                                           'dropout_140[0][0]']
#
#  layer_normalization_95 (LayerN  (None, 3, 17)       34          ['tf.__operators__.add_95[0][0]']
#  ormalization)
#
#  multi_head_attention_61 (Multi  (None, None, 17)    1224        ['layer_normalization_95[0][0]',
#  HeadAttention)                                                   'layer_normalization_95[0][0]',
#                                                                   'layer_normalization_95[0][0]']
#
#  dropout_149 (Dropout)          (None, None, 17)     0           ['multi_head_attention_61[0][0]']
#
#  tf.__operators__.add_102 (TFOp  (None, 3, 17)       0           ['dropout_149[0][0]',
#  Lambda)                                                          'layer_normalization_95[0][0]']
#
#  layer_normalization_102 (Layer  (None, 3, 17)       34          ['tf.__operators__.add_102[0][0]'
#  Normalization)                                                  ]
#
#  multi_head_attention_62 (Multi  (None, None, 17)    1224        ['layer_normalization_102[0][0]',
#  HeadAttention)                                                   'input_7[0][0]',
#                                                                   'input_7[0][0]']
#
#  dropout_150 (Dropout)          (None, None, 17)     0           ['multi_head_attention_62[0][0]']
#
#  tf.__operators__.add_103 (TFOp  (None, 3, 17)       0           ['layer_normalization_102[0][0]',
#  Lambda)                                                          'dropout_150[0][0]']
#
#  layer_normalization_103 (Layer  (None, 3, 17)       34          ['tf.__operators__.add_103[0][0]'
#  Normalization)                                                  ]
#
#  positionwise_feed_forward_41 (  (None, 3, 17)       2257        ['layer_normalization_103[0][0]']
#  PositionwiseFeedForward)
#
#  dropout_152 (Dropout)          (None, 3, 17)        0           ['positionwise_feed_forward_41[0]
#                                                                  [0]']
#
#  tf.__operators__.add_104 (TFOp  (None, 3, 17)       0           ['layer_normalization_103[0][0]',
#  Lambda)                                                          'dropout_152[0][0]']
#
#  layer_normalization_104 (Layer  (None, 3, 17)       34          ['tf.__operators__.add_104[0][0]'
#  Normalization)                                                  ]
#
#  global_average_pooling1d_6 (Gl  (None, 3)           0           ['layer_normalization_104[0][0]']
#  obalAveragePooling1D)
#
#  dropout_153 (Dropout)          (None, 3)            0           ['global_average_pooling1d_6[0][0
#                                                                  ]']
#
#  dense_342 (Dense)              (None, 1)            4           ['dropout_153[0][0]']
#
# ==================================================================================================
# Total params: 8,360
# Trainable params: 8,360
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def root_mean_squared_error(y_true, y_pred):
    return tf.keras.backend.sqrt(
        tf.keras.backend.mean(
            tf.keras.backend.square(
                y_pred - y_true
            )
        ) + 1e-9
    )

# Define the learning rate for Adam optimizer
learning_rate = 0.01

# Compile the manual model
manul_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate), loss='mse',  metrics=['mae', 'mse', root_mean_squared_error])

# %%
# Define the parameters for training
epochs = 200
batch_size = 32

# Convert the data to float32
train_data_inputs = train_data_inputs.astype('float32')
train_data_targets = train_data_targets.astype('float32')

val_data_inputs = val_data_inputs.astype('float32')
val_data_targets = val_data_targets.astype('float32')

train_data_inputs.shape, train_data_targets.shape, val_data_inputs.shape, val_data_targets.shape
# Out:
# ((35, 3, 17), (35,), (8, 3, 17), (8,))

# %%
# Train the manual model
manul_model.fit(train_data_inputs, train_data_targets,
          validation_data=(val_data_inputs, val_data_targets),
          epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/200
# 2/2 [==============================] - 8s 1s/step - loss: 0.2139 - mae: 0.3867 - mse: 0.2139 - root_mean_squared_error: 0.4461 - val_loss: 0.1888 - val_mae: 0.3843 - val_mse: 0.1888 - val_root_mean_squared_error: 0.4345
# Epoch 2/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1761 - mae: 0.3364 - mse: 0.1761 - root_mean_squared_error: 0.3787 - val_loss: 0.1413 - val_mae: 0.3165 - val_mse: 0.1413 - val_root_mean_squared_error: 0.3759
# Epoch 3/200
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1404 - mae: 0.2836 - mse: 0.1404 - root_mean_squared_error: 0.3663 - val_loss: 0.1018 - val_mae: 0.2570 - val_mse: 0.1018 - val_root_mean_squared_error: 0.3191
# Epoch 4/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0996 - mae: 0.2410 - mse: 0.0996 - root_mean_squared_error: 0.3237 - val_loss: 0.0716 - val_mae: 0.2031 - val_mse: 0.0716 - val_root_mean_squared_error: 0.2676
# Epoch 5/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0834 - mae: 0.2330 - mse: 0.0834 - root_mean_squared_error: 0.2363 - val_loss: 0.0525 - val_mae: 0.1616 - val_mse: 0.0525 - val_root_mean_squared_error: 0.2290
# Epoch 6/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0695 - mae: 0.2202 - mse: 0.0695 - root_mean_squared_error: 0.2223 - val_loss: 0.0432 - val_mae: 0.1516 - val_mse: 0.0432 - val_root_mean_squared_error: 0.2078
# Epoch 7/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0680 - mae: 0.2112 - mse: 0.0680 - root_mean_squared_error: 0.2911 - val_loss: 0.0410 - val_mae: 0.1516 - val_mse: 0.0410 - val_root_mean_squared_error: 0.2025
# Epoch 8/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0773 - mae: 0.2281 - mse: 0.0773 - root_mean_squared_error: 0.2723 - val_loss: 0.0426 - val_mae: 0.1586 - val_mse: 0.0426 - val_root_mean_squared_error: 0.2064
# Epoch 9/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0796 - mae: 0.2485 - mse: 0.0796 - root_mean_squared_error: 0.3203 - val_loss: 0.0434 - val_mae: 0.1628 - val_mse: 0.0434 - val_root_mean_squared_error: 0.2083
# Epoch 10/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0692 - mae: 0.2189 - mse: 0.0692 - root_mean_squared_error: 0.3234 - val_loss: 0.0437 - val_mae: 0.1644 - val_mse: 0.0437 - val_root_mean_squared_error: 0.2091
# Epoch 11/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0692 - mae: 0.2223 - mse: 0.0692 - root_mean_squared_error: 0.2509 - val_loss: 0.0428 - val_mae: 0.1592 - val_mse: 0.0428 - val_root_mean_squared_error: 0.2068
# Epoch 12/200
# 2/2 [==============================] - 0s 231ms/step - loss: 0.0830 - mae: 0.2390 - mse: 0.0830 - root_mean_squared_error: 0.2285 - val_loss: 0.0413 - val_mae: 0.1527 - val_mse: 0.0413 - val_root_mean_squared_error: 0.2032
# Epoch 13/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0542 - mae: 0.1858 - mse: 0.0542 - root_mean_squared_error: 0.1960 - val_loss: 0.0411 - val_mae: 0.1516 - val_mse: 0.0411 - val_root_mean_squared_error: 0.2026
# Epoch 14/200
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0863 - mae: 0.2411 - mse: 0.0863 - root_mean_squared_error: 0.3144 - val_loss: 0.0424 - val_mae: 0.1515 - val_mse: 0.0424 - val_root_mean_squared_error: 0.2059
# Epoch 15/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0660 - mae: 0.1951 - mse: 0.0660 - root_mean_squared_error: 0.2141 - val_loss: 0.0461 - val_mae: 0.1525 - val_mse: 0.0461 - val_root_mean_squared_error: 0.2146
# Epoch 16/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0647 - mae: 0.2016 - mse: 0.0647 - root_mean_squared_error: 0.1613 - val_loss: 0.0509 - val_mae: 0.1597 - val_mse: 0.0509 - val_root_mean_squared_error: 0.2256
# Epoch 17/200
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0624 - mae: 0.1989 - mse: 0.0624 - root_mean_squared_error: 0.2257 - val_loss: 0.0556 - val_mae: 0.1661 - val_mse: 0.0556 - val_root_mean_squared_error: 0.2357
# Epoch 18/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0686 - mae: 0.2121 - mse: 0.0686 - root_mean_squared_error: 0.2571 - val_loss: 0.0596 - val_mae: 0.1742 - val_mse: 0.0596 - val_root_mean_squared_error: 0.2442
# Epoch 19/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0733 - mae: 0.2109 - mse: 0.0733 - root_mean_squared_error: 0.2101 - val_loss: 0.0621 - val_mae: 0.1809 - val_mse: 0.0621 - val_root_mean_squared_error: 0.2492
# Epoch 20/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0755 - mae: 0.2130 - mse: 0.0755 - root_mean_squared_error: 0.3387 - val_loss: 0.0617 - val_mae: 0.1798 - val_mse: 0.0617 - val_root_mean_squared_error: 0.2484
# Epoch 21/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0824 - mae: 0.2305 - mse: 0.0824 - root_mean_squared_error: 0.2533 - val_loss: 0.0602 - val_mae: 0.1758 - val_mse: 0.0602 - val_root_mean_squared_error: 0.2453
# Epoch 22/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0920 - mae: 0.2329 - mse: 0.0920 - root_mean_squared_error: 0.2145 - val_loss: 0.0601 - val_mae: 0.1756 - val_mse: 0.0601 - val_root_mean_squared_error: 0.2452
# Epoch 23/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0705 - mae: 0.2110 - mse: 0.0705 - root_mean_squared_error: 0.2414 - val_loss: 0.0601 - val_mae: 0.1756 - val_mse: 0.0601 - val_root_mean_squared_error: 0.2452
# Epoch 24/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0680 - mae: 0.2052 - mse: 0.0680 - root_mean_squared_error: 0.2610 - val_loss: 0.0596 - val_mae: 0.1742 - val_mse: 0.0596 - val_root_mean_squared_error: 0.2442
# Epoch 25/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0735 - mae: 0.2237 - mse: 0.0735 - root_mean_squared_error: 0.3298 - val_loss: 0.0546 - val_mae: 0.1640 - val_mse: 0.0546 - val_root_mean_squared_error: 0.2337
# Epoch 26/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0696 - mae: 0.2139 - mse: 0.0696 - root_mean_squared_error: 0.2438 - val_loss: 0.0477 - val_mae: 0.1552 - val_mse: 0.0477 - val_root_mean_squared_error: 0.2184
# Epoch 27/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0677 - mae: 0.2150 - mse: 0.0677 - root_mean_squared_error: 0.2453 - val_loss: 0.0439 - val_mae: 0.1514 - val_mse: 0.0439 - val_root_mean_squared_error: 0.2094
# Epoch 28/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0661 - mae: 0.2106 - mse: 0.0661 - root_mean_squared_error: 0.2930 - val_loss: 0.0420 - val_mae: 0.1514 - val_mse: 0.0420 - val_root_mean_squared_error: 0.2049
# Epoch 29/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0730 - mae: 0.2189 - mse: 0.0730 - root_mean_squared_error: 0.2614 - val_loss: 0.0411 - val_mae: 0.1514 - val_mse: 0.0411 - val_root_mean_squared_error: 0.2027
# Epoch 30/200
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0763 - mae: 0.2309 - mse: 0.0763 - root_mean_squared_error: 0.3223 - val_loss: 0.0411 - val_mae: 0.1514 - val_mse: 0.0411 - val_root_mean_squared_error: 0.2027
# Epoch 31/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0727 - mae: 0.2122 - mse: 0.0727 - root_mean_squared_error: 0.2292 - val_loss: 0.0414 - val_mae: 0.1532 - val_mse: 0.0414 - val_root_mean_squared_error: 0.2035
# Epoch 32/200
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0750 - mae: 0.2136 - mse: 0.0750 - root_mean_squared_error: 0.2633 - val_loss: 0.0417 - val_mae: 0.1547 - val_mse: 0.0417 - val_root_mean_squared_error: 0.2042
# Epoch 33/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0837 - mae: 0.2416 - mse: 0.0837 - root_mean_squared_error: 0.2633 - val_loss: 0.0414 - val_mae: 0.1528 - val_mse: 0.0414 - val_root_mean_squared_error: 0.2035
# Epoch 34/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0806 - mae: 0.2422 - mse: 0.0806 - root_mean_squared_error: 0.3033 - val_loss: 0.0411 - val_mae: 0.1513 - val_mse: 0.0411 - val_root_mean_squared_error: 0.2028
# Epoch 35/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0688 - mae: 0.2235 - mse: 0.0688 - root_mean_squared_error: 0.2341 - val_loss: 0.0412 - val_mae: 0.1511 - val_mse: 0.0412 - val_root_mean_squared_error: 0.2031
# Epoch 36/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0696 - mae: 0.2165 - mse: 0.0696 - root_mean_squared_error: 0.2647 - val_loss: 0.0419 - val_mae: 0.1509 - val_mse: 0.0419 - val_root_mean_squared_error: 0.2047
# Epoch 37/200
# 2/2 [==============================] - 0s 183ms/step - loss: 0.0709 - mae: 0.2201 - mse: 0.0709 - root_mean_squared_error: 0.2081 - val_loss: 0.0438 - val_mae: 0.1505 - val_mse: 0.0438 - val_root_mean_squared_error: 0.2094
# Epoch 38/200
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0665 - mae: 0.2144 - mse: 0.0665 - root_mean_squared_error: 0.2625 - val_loss: 0.0465 - val_mae: 0.1534 - val_mse: 0.0465 - val_root_mean_squared_error: 0.2157
# Epoch 39/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0590 - mae: 0.2028 - mse: 0.0590 - root_mean_squared_error: 0.1795 - val_loss: 0.0476 - val_mae: 0.1552 - val_mse: 0.0476 - val_root_mean_squared_error: 0.2182
# Epoch 40/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0573 - mae: 0.1897 - mse: 0.0573 - root_mean_squared_error: 0.3547 - val_loss: 0.0455 - val_mae: 0.1515 - val_mse: 0.0455 - val_root_mean_squared_error: 0.2132
# Epoch 41/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0562 - mae: 0.1911 - mse: 0.0562 - root_mean_squared_error: 0.2125 - val_loss: 0.0424 - val_mae: 0.1512 - val_mse: 0.0424 - val_root_mean_squared_error: 0.2059
# Epoch 42/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0601 - mae: 0.1963 - mse: 0.0601 - root_mean_squared_error: 0.1825 - val_loss: 0.0411 - val_mae: 0.1513 - val_mse: 0.0411 - val_root_mean_squared_error: 0.2028
# Epoch 43/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0613 - mae: 0.1989 - mse: 0.0613 - root_mean_squared_error: 0.2412 - val_loss: 0.0412 - val_mae: 0.1512 - val_mse: 0.0412 - val_root_mean_squared_error: 0.2029
# Epoch 44/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0630 - mae: 0.2085 - mse: 0.0630 - root_mean_squared_error: 0.2553 - val_loss: 0.0412 - val_mae: 0.1511 - val_mse: 0.0412 - val_root_mean_squared_error: 0.2029
# Epoch 45/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0738 - mae: 0.2271 - mse: 0.0738 - root_mean_squared_error: 0.3420 - val_loss: 0.0412 - val_mae: 0.1509 - val_mse: 0.0412 - val_root_mean_squared_error: 0.2030
# Epoch 46/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0614 - mae: 0.1919 - mse: 0.0614 - root_mean_squared_error: 0.2837 - val_loss: 0.0416 - val_mae: 0.1497 - val_mse: 0.0416 - val_root_mean_squared_error: 0.2039
# Epoch 47/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0669 - mae: 0.2209 - mse: 0.0669 - root_mean_squared_error: 0.2254 - val_loss: 0.0421 - val_mae: 0.1495 - val_mse: 0.0421 - val_root_mean_squared_error: 0.2051
# Epoch 48/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0678 - mae: 0.2135 - mse: 0.0678 - root_mean_squared_error: 0.2181 - val_loss: 0.0419 - val_mae: 0.1513 - val_mse: 0.0419 - val_root_mean_squared_error: 0.2048
# Epoch 49/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0729 - mae: 0.2145 - mse: 0.0729 - root_mean_squared_error: 0.2666 - val_loss: 0.0426 - val_mae: 0.1511 - val_mse: 0.0426 - val_root_mean_squared_error: 0.2064
# Epoch 50/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0638 - mae: 0.2100 - mse: 0.0638 - root_mean_squared_error: 0.2322 - val_loss: 0.0450 - val_mae: 0.1536 - val_mse: 0.0450 - val_root_mean_squared_error: 0.2122
# Epoch 51/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0721 - mae: 0.2204 - mse: 0.0721 - root_mean_squared_error: 0.3384 - val_loss: 0.0594 - val_mae: 0.1788 - val_mse: 0.0594 - val_root_mean_squared_error: 0.2436
# Epoch 52/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0629 - mae: 0.2089 - mse: 0.0629 - root_mean_squared_error: 0.2430 - val_loss: 0.0673 - val_mae: 0.1927 - val_mse: 0.0673 - val_root_mean_squared_error: 0.2594
# Epoch 53/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0628 - mae: 0.2058 - mse: 0.0628 - root_mean_squared_error: 0.2670 - val_loss: 0.0703 - val_mae: 0.2020 - val_mse: 0.0703 - val_root_mean_squared_error: 0.2652
# Epoch 54/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0599 - mae: 0.1940 - mse: 0.0599 - root_mean_squared_error: 0.2994 - val_loss: 0.0694 - val_mae: 0.2002 - val_mse: 0.0694 - val_root_mean_squared_error: 0.2634
# Epoch 55/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0661 - mae: 0.2133 - mse: 0.0661 - root_mean_squared_error: 0.2172 - val_loss: 0.0662 - val_mae: 0.1917 - val_mse: 0.0662 - val_root_mean_squared_error: 0.2572
# Epoch 56/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0568 - mae: 0.1889 - mse: 0.0568 - root_mean_squared_error: 0.2137 - val_loss: 0.0703 - val_mae: 0.2008 - val_mse: 0.0703 - val_root_mean_squared_error: 0.2652
# Epoch 57/200
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0608 - mae: 0.2098 - mse: 0.0608 - root_mean_squared_error: 0.2383 - val_loss: 0.0669 - val_mae: 0.1932 - val_mse: 0.0669 - val_root_mean_squared_error: 0.2586
# Epoch 58/200
# 2/2 [==============================] - 0s 208ms/step - loss: 0.0700 - mae: 0.2164 - mse: 0.0700 - root_mean_squared_error: 0.1977 - val_loss: 0.0564 - val_mae: 0.1686 - val_mse: 0.0564 - val_root_mean_squared_error: 0.2375
# Epoch 59/200
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0723 - mae: 0.2125 - mse: 0.0723 - root_mean_squared_error: 0.2402 - val_loss: 0.0529 - val_mae: 0.1614 - val_mse: 0.0529 - val_root_mean_squared_error: 0.2301
# Epoch 60/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0658 - mae: 0.2154 - mse: 0.0658 - root_mean_squared_error: 0.2289 - val_loss: 0.0580 - val_mae: 0.1713 - val_mse: 0.0580 - val_root_mean_squared_error: 0.2408
# Epoch 61/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0722 - mae: 0.2159 - mse: 0.0722 - root_mean_squared_error: 0.3063 - val_loss: 0.0586 - val_mae: 0.1725 - val_mse: 0.0586 - val_root_mean_squared_error: 0.2421
# Epoch 62/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0723 - mae: 0.2162 - mse: 0.0723 - root_mean_squared_error: 0.3335 - val_loss: 0.0535 - val_mae: 0.1624 - val_mse: 0.0535 - val_root_mean_squared_error: 0.2312
# Epoch 63/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0674 - mae: 0.2141 - mse: 0.0674 - root_mean_squared_error: 0.3281 - val_loss: 0.0452 - val_mae: 0.1515 - val_mse: 0.0452 - val_root_mean_squared_error: 0.2126
# Epoch 64/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0654 - mae: 0.2032 - mse: 0.0654 - root_mean_squared_error: 0.2481 - val_loss: 0.0409 - val_mae: 0.1515 - val_mse: 0.0409 - val_root_mean_squared_error: 0.2022
# Epoch 65/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0653 - mae: 0.2070 - mse: 0.0653 - root_mean_squared_error: 0.2442 - val_loss: 0.0411 - val_mae: 0.1529 - val_mse: 0.0411 - val_root_mean_squared_error: 0.2026
# Epoch 66/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0663 - mae: 0.2191 - mse: 0.0663 - root_mean_squared_error: 0.2640 - val_loss: 0.0412 - val_mae: 0.1535 - val_mse: 0.0412 - val_root_mean_squared_error: 0.2029
# Epoch 67/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0743 - mae: 0.2231 - mse: 0.0743 - root_mean_squared_error: 0.2930 - val_loss: 0.0410 - val_mae: 0.1522 - val_mse: 0.0410 - val_root_mean_squared_error: 0.2025
# Epoch 68/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0688 - mae: 0.2163 - mse: 0.0688 - root_mean_squared_error: 0.2893 - val_loss: 0.0410 - val_mae: 0.1515 - val_mse: 0.0410 - val_root_mean_squared_error: 0.2024
# Epoch 69/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0641 - mae: 0.2026 - mse: 0.0641 - root_mean_squared_error: 0.2299 - val_loss: 0.0408 - val_mae: 0.1515 - val_mse: 0.0408 - val_root_mean_squared_error: 0.2021
# Epoch 70/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0703 - mae: 0.2178 - mse: 0.0703 - root_mean_squared_error: 0.2373 - val_loss: 0.0412 - val_mae: 0.1515 - val_mse: 0.0412 - val_root_mean_squared_error: 0.2029
# Epoch 71/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0674 - mae: 0.2168 - mse: 0.0674 - root_mean_squared_error: 0.2320 - val_loss: 0.0428 - val_mae: 0.1515 - val_mse: 0.0428 - val_root_mean_squared_error: 0.2070
# Epoch 72/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0652 - mae: 0.2106 - mse: 0.0652 - root_mean_squared_error: 0.2102 - val_loss: 0.0454 - val_mae: 0.1515 - val_mse: 0.0454 - val_root_mean_squared_error: 0.2131
# Epoch 73/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0651 - mae: 0.2105 - mse: 0.0651 - root_mean_squared_error: 0.2336 - val_loss: 0.0486 - val_mae: 0.1564 - val_mse: 0.0486 - val_root_mean_squared_error: 0.2204
# Epoch 74/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0675 - mae: 0.2144 - mse: 0.0675 - root_mean_squared_error: 0.2697 - val_loss: 0.0510 - val_mae: 0.1596 - val_mse: 0.0510 - val_root_mean_squared_error: 0.2258
# Epoch 75/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0635 - mae: 0.2010 - mse: 0.0635 - root_mean_squared_error: 0.2201 - val_loss: 0.0531 - val_mae: 0.1621 - val_mse: 0.0531 - val_root_mean_squared_error: 0.2303
# Epoch 76/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0666 - mae: 0.2085 - mse: 0.0666 - root_mean_squared_error: 0.2092 - val_loss: 0.0553 - val_mae: 0.1659 - val_mse: 0.0553 - val_root_mean_squared_error: 0.2352
# Epoch 77/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0723 - mae: 0.2101 - mse: 0.0723 - root_mean_squared_error: 0.3523 - val_loss: 0.0554 - val_mae: 0.1661 - val_mse: 0.0554 - val_root_mean_squared_error: 0.2354
# Epoch 78/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0723 - mae: 0.2213 - mse: 0.0723 - root_mean_squared_error: 0.2587 - val_loss: 0.0533 - val_mae: 0.1623 - val_mse: 0.0533 - val_root_mean_squared_error: 0.2308
# Epoch 79/200
# 2/2 [==============================] - 0s 152ms/step - loss: 0.0629 - mae: 0.1981 - mse: 0.0629 - root_mean_squared_error: 0.2849 - val_loss: 0.0495 - val_mae: 0.1577 - val_mse: 0.0495 - val_root_mean_squared_error: 0.2225
# Epoch 80/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0616 - mae: 0.2048 - mse: 0.0616 - root_mean_squared_error: 0.3608 - val_loss: 0.0441 - val_mae: 0.1514 - val_mse: 0.0441 - val_root_mean_squared_error: 0.2100
# Epoch 81/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0628 - mae: 0.2007 - mse: 0.0628 - root_mean_squared_error: 0.2549 - val_loss: 0.0413 - val_mae: 0.1514 - val_mse: 0.0413 - val_root_mean_squared_error: 0.2031
# Epoch 82/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0683 - mae: 0.2120 - mse: 0.0683 - root_mean_squared_error: 0.1853 - val_loss: 0.0407 - val_mae: 0.1513 - val_mse: 0.0407 - val_root_mean_squared_error: 0.2017
# Epoch 83/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0719 - mae: 0.2221 - mse: 0.0719 - root_mean_squared_error: 0.2533 - val_loss: 0.0407 - val_mae: 0.1513 - val_mse: 0.0407 - val_root_mean_squared_error: 0.2017
# Epoch 84/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0638 - mae: 0.2068 - mse: 0.0638 - root_mean_squared_error: 0.3091 - val_loss: 0.0407 - val_mae: 0.1513 - val_mse: 0.0407 - val_root_mean_squared_error: 0.2017
# Epoch 85/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0642 - mae: 0.2112 - mse: 0.0642 - root_mean_squared_error: 0.2803 - val_loss: 0.0408 - val_mae: 0.1518 - val_mse: 0.0408 - val_root_mean_squared_error: 0.2019
# Epoch 86/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0702 - mae: 0.2207 - mse: 0.0702 - root_mean_squared_error: 0.2209 - val_loss: 0.0411 - val_mae: 0.1544 - val_mse: 0.0411 - val_root_mean_squared_error: 0.2028
# Epoch 87/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0740 - mae: 0.2266 - mse: 0.0740 - root_mean_squared_error: 0.2899 - val_loss: 0.0409 - val_mae: 0.1532 - val_mse: 0.0409 - val_root_mean_squared_error: 0.2021
# Epoch 88/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0626 - mae: 0.2109 - mse: 0.0626 - root_mean_squared_error: 0.2805 - val_loss: 0.0404 - val_mae: 0.1509 - val_mse: 0.0404 - val_root_mean_squared_error: 0.2010
# Epoch 89/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0605 - mae: 0.2043 - mse: 0.0605 - root_mean_squared_error: 0.2317 - val_loss: 0.0407 - val_mae: 0.1508 - val_mse: 0.0407 - val_root_mean_squared_error: 0.2017
# Epoch 90/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0621 - mae: 0.2063 - mse: 0.0621 - root_mean_squared_error: 0.2199 - val_loss: 0.0429 - val_mae: 0.1510 - val_mse: 0.0429 - val_root_mean_squared_error: 0.2071
# Epoch 91/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0599 - mae: 0.2039 - mse: 0.0599 - root_mean_squared_error: 0.2142 - val_loss: 0.0476 - val_mae: 0.1540 - val_mse: 0.0476 - val_root_mean_squared_error: 0.2182
# Epoch 92/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0702 - mae: 0.2148 - mse: 0.0702 - root_mean_squared_error: 0.1984 - val_loss: 0.0535 - val_mae: 0.1621 - val_mse: 0.0535 - val_root_mean_squared_error: 0.2313
# Epoch 93/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0663 - mae: 0.2081 - mse: 0.0663 - root_mean_squared_error: 0.2259 - val_loss: 0.0586 - val_mae: 0.1725 - val_mse: 0.0586 - val_root_mean_squared_error: 0.2421
# Epoch 94/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0706 - mae: 0.2152 - mse: 0.0706 - root_mean_squared_error: 0.2552 - val_loss: 0.0631 - val_mae: 0.1838 - val_mse: 0.0631 - val_root_mean_squared_error: 0.2512
# Epoch 95/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0657 - mae: 0.2084 - mse: 0.0657 - root_mean_squared_error: 0.2433 - val_loss: 0.0663 - val_mae: 0.1915 - val_mse: 0.0663 - val_root_mean_squared_error: 0.2575
# Epoch 96/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0706 - mae: 0.2139 - mse: 0.0706 - root_mean_squared_error: 0.3022 - val_loss: 0.0670 - val_mae: 0.1931 - val_mse: 0.0670 - val_root_mean_squared_error: 0.2588
# Epoch 97/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0682 - mae: 0.2068 - mse: 0.0682 - root_mean_squared_error: 0.2456 - val_loss: 0.0630 - val_mae: 0.1835 - val_mse: 0.0630 - val_root_mean_squared_error: 0.2510
# Epoch 98/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0703 - mae: 0.2170 - mse: 0.0703 - root_mean_squared_error: 0.1950 - val_loss: 0.0571 - val_mae: 0.1696 - val_mse: 0.0571 - val_root_mean_squared_error: 0.2389
# Epoch 99/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0744 - mae: 0.2149 - mse: 0.0744 - root_mean_squared_error: 0.3632 - val_loss: 0.0509 - val_mae: 0.1583 - val_mse: 0.0509 - val_root_mean_squared_error: 0.2256
# Epoch 100/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0620 - mae: 0.2063 - mse: 0.0620 - root_mean_squared_error: 0.2145 - val_loss: 0.0452 - val_mae: 0.1507 - val_mse: 0.0452 - val_root_mean_squared_error: 0.2125
# Epoch 101/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0646 - mae: 0.2120 - mse: 0.0646 - root_mean_squared_error: 0.2852 - val_loss: 0.0422 - val_mae: 0.1502 - val_mse: 0.0422 - val_root_mean_squared_error: 0.2053
# Epoch 102/200
# 2/2 [==============================] - 0s 162ms/step - loss: 0.0680 - mae: 0.2235 - mse: 0.0680 - root_mean_squared_error: 0.2901 - val_loss: 0.0405 - val_mae: 0.1497 - val_mse: 0.0405 - val_root_mean_squared_error: 0.2013
# Epoch 103/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0637 - mae: 0.2181 - mse: 0.0637 - root_mean_squared_error: 0.2572 - val_loss: 0.0390 - val_mae: 0.1481 - val_mse: 0.0390 - val_root_mean_squared_error: 0.1975
# Epoch 104/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0677 - mae: 0.2208 - mse: 0.0677 - root_mean_squared_error: 0.2129 - val_loss: 0.0389 - val_mae: 0.1479 - val_mse: 0.0389 - val_root_mean_squared_error: 0.1972
# Epoch 105/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0719 - mae: 0.2266 - mse: 0.0719 - root_mean_squared_error: 0.2544 - val_loss: 0.0394 - val_mae: 0.1486 - val_mse: 0.0394 - val_root_mean_squared_error: 0.1985
# Epoch 106/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0674 - mae: 0.2201 - mse: 0.0674 - root_mean_squared_error: 0.2694 - val_loss: 0.0410 - val_mae: 0.1496 - val_mse: 0.0410 - val_root_mean_squared_error: 0.2025
# Epoch 107/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0587 - mae: 0.2030 - mse: 0.0587 - root_mean_squared_error: 0.2320 - val_loss: 0.0435 - val_mae: 0.1509 - val_mse: 0.0435 - val_root_mean_squared_error: 0.2086
# Epoch 108/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0598 - mae: 0.2050 - mse: 0.0598 - root_mean_squared_error: 0.2851 - val_loss: 0.0433 - val_mae: 0.1510 - val_mse: 0.0433 - val_root_mean_squared_error: 0.2082
# Epoch 109/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0609 - mae: 0.2067 - mse: 0.0609 - root_mean_squared_error: 0.2394 - val_loss: 0.0422 - val_mae: 0.1504 - val_mse: 0.0422 - val_root_mean_squared_error: 0.2054
# Epoch 110/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0628 - mae: 0.2092 - mse: 0.0628 - root_mean_squared_error: 0.2785 - val_loss: 0.0432 - val_mae: 0.1504 - val_mse: 0.0432 - val_root_mean_squared_error: 0.2079
# Epoch 111/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0581 - mae: 0.2043 - mse: 0.0581 - root_mean_squared_error: 0.1722 - val_loss: 0.0450 - val_mae: 0.1506 - val_mse: 0.0450 - val_root_mean_squared_error: 0.2121
# Epoch 112/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0605 - mae: 0.2064 - mse: 0.0605 - root_mean_squared_error: 0.2308 - val_loss: 0.0470 - val_mae: 0.1528 - val_mse: 0.0470 - val_root_mean_squared_error: 0.2167
# Epoch 113/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0607 - mae: 0.2035 - mse: 0.0607 - root_mean_squared_error: 0.2738 - val_loss: 0.0474 - val_mae: 0.1534 - val_mse: 0.0474 - val_root_mean_squared_error: 0.2177
# Epoch 114/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0647 - mae: 0.2123 - mse: 0.0647 - root_mean_squared_error: 0.2100 - val_loss: 0.0454 - val_mae: 0.1503 - val_mse: 0.0454 - val_root_mean_squared_error: 0.2132
# Epoch 115/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0609 - mae: 0.2046 - mse: 0.0609 - root_mean_squared_error: 0.3170 - val_loss: 0.0425 - val_mae: 0.1495 - val_mse: 0.0425 - val_root_mean_squared_error: 0.2062
# Epoch 116/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0661 - mae: 0.2146 - mse: 0.0661 - root_mean_squared_error: 0.2629 - val_loss: 0.0409 - val_mae: 0.1491 - val_mse: 0.0409 - val_root_mean_squared_error: 0.2022
# Epoch 117/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0662 - mae: 0.2183 - mse: 0.0662 - root_mean_squared_error: 0.2250 - val_loss: 0.0417 - val_mae: 0.1504 - val_mse: 0.0417 - val_root_mean_squared_error: 0.2043
# Epoch 118/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0558 - mae: 0.1981 - mse: 0.0558 - root_mean_squared_error: 0.2397 - val_loss: 0.0422 - val_mae: 0.1514 - val_mse: 0.0422 - val_root_mean_squared_error: 0.2054
# Epoch 119/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0618 - mae: 0.2145 - mse: 0.0618 - root_mean_squared_error: 0.2616 - val_loss: 0.0420 - val_mae: 0.1520 - val_mse: 0.0420 - val_root_mean_squared_error: 0.2049
# Epoch 120/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0572 - mae: 0.1993 - mse: 0.0572 - root_mean_squared_error: 0.2232 - val_loss: 0.0428 - val_mae: 0.1529 - val_mse: 0.0428 - val_root_mean_squared_error: 0.2070
# Epoch 121/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0613 - mae: 0.2087 - mse: 0.0613 - root_mean_squared_error: 0.2138 - val_loss: 0.0452 - val_mae: 0.1532 - val_mse: 0.0452 - val_root_mean_squared_error: 0.2125
# Epoch 122/200
# 2/2 [==============================] - 0s 205ms/step - loss: 0.0642 - mae: 0.2052 - mse: 0.0642 - root_mean_squared_error: 0.2929 - val_loss: 0.0475 - val_mae: 0.1547 - val_mse: 0.0475 - val_root_mean_squared_error: 0.2178
# Epoch 123/200
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0641 - mae: 0.2056 - mse: 0.0641 - root_mean_squared_error: 0.2546 - val_loss: 0.0472 - val_mae: 0.1545 - val_mse: 0.0472 - val_root_mean_squared_error: 0.2173
# Epoch 124/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0556 - mae: 0.1932 - mse: 0.0556 - root_mean_squared_error: 0.2341 - val_loss: 0.0448 - val_mae: 0.1518 - val_mse: 0.0448 - val_root_mean_squared_error: 0.2116
# Epoch 125/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0661 - mae: 0.2079 - mse: 0.0661 - root_mean_squared_error: 0.2831 - val_loss: 0.0432 - val_mae: 0.1518 - val_mse: 0.0432 - val_root_mean_squared_error: 0.2078
# Epoch 126/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0596 - mae: 0.1995 - mse: 0.0596 - root_mean_squared_error: 0.2423 - val_loss: 0.0431 - val_mae: 0.1517 - val_mse: 0.0431 - val_root_mean_squared_error: 0.2076
# Epoch 127/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0604 - mae: 0.2045 - mse: 0.0604 - root_mean_squared_error: 0.2613 - val_loss: 0.0429 - val_mae: 0.1517 - val_mse: 0.0429 - val_root_mean_squared_error: 0.2072
# Epoch 128/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0587 - mae: 0.1997 - mse: 0.0587 - root_mean_squared_error: 0.1941 - val_loss: 0.0423 - val_mae: 0.1518 - val_mse: 0.0423 - val_root_mean_squared_error: 0.2056
# Epoch 129/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0605 - mae: 0.2018 - mse: 0.0605 - root_mean_squared_error: 0.2616 - val_loss: 0.0423 - val_mae: 0.1518 - val_mse: 0.0423 - val_root_mean_squared_error: 0.2057
# Epoch 130/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0579 - mae: 0.1941 - mse: 0.0579 - root_mean_squared_error: 0.2043 - val_loss: 0.0430 - val_mae: 0.1519 - val_mse: 0.0430 - val_root_mean_squared_error: 0.2073
# Epoch 131/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0628 - mae: 0.2060 - mse: 0.0628 - root_mean_squared_error: 0.2608 - val_loss: 0.0443 - val_mae: 0.1521 - val_mse: 0.0443 - val_root_mean_squared_error: 0.2105
# Epoch 132/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0612 - mae: 0.2040 - mse: 0.0612 - root_mean_squared_error: 0.1740 - val_loss: 0.0459 - val_mae: 0.1525 - val_mse: 0.0459 - val_root_mean_squared_error: 0.2141
# Epoch 133/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0602 - mae: 0.2027 - mse: 0.0602 - root_mean_squared_error: 0.2022 - val_loss: 0.0479 - val_mae: 0.1552 - val_mse: 0.0479 - val_root_mean_squared_error: 0.2189
# Epoch 134/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0548 - mae: 0.1907 - mse: 0.0548 - root_mean_squared_error: 0.2972 - val_loss: 0.0483 - val_mae: 0.1555 - val_mse: 0.0483 - val_root_mean_squared_error: 0.2197
# Epoch 135/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0609 - mae: 0.1957 - mse: 0.0609 - root_mean_squared_error: 0.1974 - val_loss: 0.0453 - val_mae: 0.1537 - val_mse: 0.0453 - val_root_mean_squared_error: 0.2128
# Epoch 136/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0597 - mae: 0.2003 - mse: 0.0597 - root_mean_squared_error: 0.2158 - val_loss: 0.0431 - val_mae: 0.1533 - val_mse: 0.0431 - val_root_mean_squared_error: 0.2076
# Epoch 137/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0541 - mae: 0.1922 - mse: 0.0541 - root_mean_squared_error: 0.2107 - val_loss: 0.0422 - val_mae: 0.1525 - val_mse: 0.0422 - val_root_mean_squared_error: 0.2055
# Epoch 138/200
# 2/2 [==============================] - 0s 91ms/step - loss: 0.0586 - mae: 0.1969 - mse: 0.0586 - root_mean_squared_error: 0.2086 - val_loss: 0.0422 - val_mae: 0.1519 - val_mse: 0.0422 - val_root_mean_squared_error: 0.2054
# Epoch 139/200
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0563 - mae: 0.1983 - mse: 0.0563 - root_mean_squared_error: 0.3293 - val_loss: 0.0429 - val_mae: 0.1519 - val_mse: 0.0429 - val_root_mean_squared_error: 0.2071
# Epoch 140/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0553 - mae: 0.1941 - mse: 0.0553 - root_mean_squared_error: 0.1937 - val_loss: 0.0442 - val_mae: 0.1526 - val_mse: 0.0442 - val_root_mean_squared_error: 0.2102
# Epoch 141/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0528 - mae: 0.1888 - mse: 0.0528 - root_mean_squared_error: 0.2525 - val_loss: 0.0450 - val_mae: 0.1534 - val_mse: 0.0450 - val_root_mean_squared_error: 0.2122
# Epoch 142/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0634 - mae: 0.2005 - mse: 0.0634 - root_mean_squared_error: 0.2270 - val_loss: 0.0436 - val_mae: 0.1538 - val_mse: 0.0436 - val_root_mean_squared_error: 0.2088
# Epoch 143/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0507 - mae: 0.1871 - mse: 0.0507 - root_mean_squared_error: 0.2265 - val_loss: 0.0421 - val_mae: 0.1537 - val_mse: 0.0421 - val_root_mean_squared_error: 0.2051
# Epoch 144/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0519 - mae: 0.1892 - mse: 0.0519 - root_mean_squared_error: 0.2440 - val_loss: 0.0405 - val_mae: 0.1536 - val_mse: 0.0405 - val_root_mean_squared_error: 0.2014
# Epoch 145/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0583 - mae: 0.1977 - mse: 0.0583 - root_mean_squared_error: 0.1903 - val_loss: 0.0388 - val_mae: 0.1526 - val_mse: 0.0388 - val_root_mean_squared_error: 0.1969
# Epoch 146/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0565 - mae: 0.1968 - mse: 0.0565 - root_mean_squared_error: 0.1679 - val_loss: 0.0381 - val_mae: 0.1546 - val_mse: 0.0381 - val_root_mean_squared_error: 0.1953
# Epoch 147/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0521 - mae: 0.1894 - mse: 0.0521 - root_mean_squared_error: 0.2832 - val_loss: 0.0352 - val_mae: 0.1434 - val_mse: 0.0352 - val_root_mean_squared_error: 0.1875
# Epoch 148/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0576 - mae: 0.1925 - mse: 0.0576 - root_mean_squared_error: 0.2086 - val_loss: 0.0382 - val_mae: 0.1508 - val_mse: 0.0382 - val_root_mean_squared_error: 0.1953
# Epoch 149/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0607 - mae: 0.2010 - mse: 0.0607 - root_mean_squared_error: 0.2562 - val_loss: 0.0353 - val_mae: 0.1530 - val_mse: 0.0353 - val_root_mean_squared_error: 0.1878
# Epoch 150/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0485 - mae: 0.1815 - mse: 0.0485 - root_mean_squared_error: 0.1896 - val_loss: 0.0445 - val_mae: 0.1718 - val_mse: 0.0445 - val_root_mean_squared_error: 0.2109
# Epoch 151/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0537 - mae: 0.1876 - mse: 0.0537 - root_mean_squared_error: 0.2068 - val_loss: 0.0599 - val_mae: 0.1817 - val_mse: 0.0599 - val_root_mean_squared_error: 0.2448
# Epoch 152/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0615 - mae: 0.1991 - mse: 0.0615 - root_mean_squared_error: 0.1939 - val_loss: 0.0506 - val_mae: 0.1730 - val_mse: 0.0506 - val_root_mean_squared_error: 0.2250
# Epoch 153/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0517 - mae: 0.1918 - mse: 0.0517 - root_mean_squared_error: 0.2197 - val_loss: 0.0710 - val_mae: 0.2032 - val_mse: 0.0710 - val_root_mean_squared_error: 0.2664
# Epoch 154/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0528 - mae: 0.1862 - mse: 0.0528 - root_mean_squared_error: 0.1730 - val_loss: 0.0741 - val_mae: 0.2095 - val_mse: 0.0741 - val_root_mean_squared_error: 0.2723
# Epoch 155/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0659 - mae: 0.2055 - mse: 0.0659 - root_mean_squared_error: 0.3715 - val_loss: 0.0673 - val_mae: 0.1949 - val_mse: 0.0673 - val_root_mean_squared_error: 0.2594
# Epoch 156/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0710 - mae: 0.2093 - mse: 0.0710 - root_mean_squared_error: 0.2413 - val_loss: 0.0568 - val_mae: 0.1705 - val_mse: 0.0568 - val_root_mean_squared_error: 0.2382
# Epoch 157/200
# 2/2 [==============================] - 0s 181ms/step - loss: 0.0675 - mae: 0.2065 - mse: 0.0675 - root_mean_squared_error: 0.2198 - val_loss: 0.0504 - val_mae: 0.1593 - val_mse: 0.0504 - val_root_mean_squared_error: 0.2244
# Epoch 158/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0645 - mae: 0.2015 - mse: 0.0645 - root_mean_squared_error: 0.3233 - val_loss: 0.0449 - val_mae: 0.1522 - val_mse: 0.0449 - val_root_mean_squared_error: 0.2120
# Epoch 159/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0647 - mae: 0.2044 - mse: 0.0647 - root_mean_squared_error: 0.2282 - val_loss: 0.0420 - val_mae: 0.1522 - val_mse: 0.0420 - val_root_mean_squared_error: 0.2049
# Epoch 160/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0622 - mae: 0.2017 - mse: 0.0622 - root_mean_squared_error: 0.2247 - val_loss: 0.0417 - val_mae: 0.1522 - val_mse: 0.0417 - val_root_mean_squared_error: 0.2042
# Epoch 161/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0631 - mae: 0.2032 - mse: 0.0631 - root_mean_squared_error: 0.2918 - val_loss: 0.0416 - val_mae: 0.1521 - val_mse: 0.0416 - val_root_mean_squared_error: 0.2040
# Epoch 162/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0622 - mae: 0.2023 - mse: 0.0622 - root_mean_squared_error: 0.2464 - val_loss: 0.0414 - val_mae: 0.1521 - val_mse: 0.0414 - val_root_mean_squared_error: 0.2034
# Epoch 163/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0615 - mae: 0.1990 - mse: 0.0615 - root_mean_squared_error: 0.1841 - val_loss: 0.0414 - val_mae: 0.1521 - val_mse: 0.0414 - val_root_mean_squared_error: 0.2034
# Epoch 164/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0655 - mae: 0.2109 - mse: 0.0655 - root_mean_squared_error: 0.2521 - val_loss: 0.0417 - val_mae: 0.1521 - val_mse: 0.0417 - val_root_mean_squared_error: 0.2043
# Epoch 165/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0643 - mae: 0.2056 - mse: 0.0643 - root_mean_squared_error: 0.2485 - val_loss: 0.0427 - val_mae: 0.1521 - val_mse: 0.0427 - val_root_mean_squared_error: 0.2067
# Epoch 166/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0621 - mae: 0.2024 - mse: 0.0621 - root_mean_squared_error: 0.2204 - val_loss: 0.0452 - val_mae: 0.1520 - val_mse: 0.0452 - val_root_mean_squared_error: 0.2127
# Epoch 167/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0638 - mae: 0.2041 - mse: 0.0638 - root_mean_squared_error: 0.2041 - val_loss: 0.0496 - val_mae: 0.1580 - val_mse: 0.0496 - val_root_mean_squared_error: 0.2227
# Epoch 168/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0638 - mae: 0.2007 - mse: 0.0638 - root_mean_squared_error: 0.2238 - val_loss: 0.0549 - val_mae: 0.1658 - val_mse: 0.0549 - val_root_mean_squared_error: 0.2343
# Epoch 169/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0690 - mae: 0.2109 - mse: 0.0690 - root_mean_squared_error: 0.3314 - val_loss: 0.0594 - val_mae: 0.1747 - val_mse: 0.0594 - val_root_mean_squared_error: 0.2438
# Epoch 170/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0686 - mae: 0.2077 - mse: 0.0686 - root_mean_squared_error: 0.2233 - val_loss: 0.0628 - val_mae: 0.1835 - val_mse: 0.0628 - val_root_mean_squared_error: 0.2507
# Epoch 171/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0706 - mae: 0.2065 - mse: 0.0706 - root_mean_squared_error: 0.2542 - val_loss: 0.0637 - val_mae: 0.1857 - val_mse: 0.0637 - val_root_mean_squared_error: 0.2524
# Epoch 172/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0720 - mae: 0.2118 - mse: 0.0720 - root_mean_squared_error: 0.3362 - val_loss: 0.0608 - val_mae: 0.1781 - val_mse: 0.0608 - val_root_mean_squared_error: 0.2466
# Epoch 173/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0699 - mae: 0.2084 - mse: 0.0699 - root_mean_squared_error: 0.1737 - val_loss: 0.0566 - val_mae: 0.1690 - val_mse: 0.0566 - val_root_mean_squared_error: 0.2379
# Epoch 174/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0650 - mae: 0.2018 - mse: 0.0650 - root_mean_squared_error: 0.2082 - val_loss: 0.0540 - val_mae: 0.1635 - val_mse: 0.0540 - val_root_mean_squared_error: 0.2323
# Epoch 175/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0658 - mae: 0.2057 - mse: 0.0658 - root_mean_squared_error: 0.2443 - val_loss: 0.0531 - val_mae: 0.1623 - val_mse: 0.0531 - val_root_mean_squared_error: 0.2304
# Epoch 176/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0641 - mae: 0.2021 - mse: 0.0641 - root_mean_squared_error: 0.2774 - val_loss: 0.0506 - val_mae: 0.1593 - val_mse: 0.0506 - val_root_mean_squared_error: 0.2249
# Epoch 177/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0628 - mae: 0.2044 - mse: 0.0628 - root_mean_squared_error: 0.1936 - val_loss: 0.0471 - val_mae: 0.1545 - val_mse: 0.0471 - val_root_mean_squared_error: 0.2171
# Epoch 178/200
# 2/2 [==============================] - 0s 128ms/step - loss: 0.0632 - mae: 0.2015 - mse: 0.0632 - root_mean_squared_error: 0.2164 - val_loss: 0.0451 - val_mae: 0.1519 - val_mse: 0.0451 - val_root_mean_squared_error: 0.2123
# Epoch 179/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0631 - mae: 0.2008 - mse: 0.0631 - root_mean_squared_error: 0.1918 - val_loss: 0.0440 - val_mae: 0.1518 - val_mse: 0.0440 - val_root_mean_squared_error: 0.2097
# Epoch 180/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0622 - mae: 0.2020 - mse: 0.0622 - root_mean_squared_error: 0.2415 - val_loss: 0.0432 - val_mae: 0.1519 - val_mse: 0.0432 - val_root_mean_squared_error: 0.2079
# Epoch 181/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0622 - mae: 0.2061 - mse: 0.0622 - root_mean_squared_error: 0.2322 - val_loss: 0.0421 - val_mae: 0.1518 - val_mse: 0.0421 - val_root_mean_squared_error: 0.2051
# Epoch 182/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0649 - mae: 0.2067 - mse: 0.0649 - root_mean_squared_error: 0.2450 - val_loss: 0.0416 - val_mae: 0.1518 - val_mse: 0.0416 - val_root_mean_squared_error: 0.2039
# Epoch 183/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0671 - mae: 0.2160 - mse: 0.0671 - root_mean_squared_error: 0.3038 - val_loss: 0.0415 - val_mae: 0.1519 - val_mse: 0.0415 - val_root_mean_squared_error: 0.2038
# Epoch 184/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0673 - mae: 0.2142 - mse: 0.0673 - root_mean_squared_error: 0.2175 - val_loss: 0.0416 - val_mae: 0.1519 - val_mse: 0.0416 - val_root_mean_squared_error: 0.2041
# Epoch 185/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0647 - mae: 0.2085 - mse: 0.0647 - root_mean_squared_error: 0.2107 - val_loss: 0.0420 - val_mae: 0.1519 - val_mse: 0.0420 - val_root_mean_squared_error: 0.2048
# Epoch 186/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0633 - mae: 0.2067 - mse: 0.0633 - root_mean_squared_error: 0.2483 - val_loss: 0.0427 - val_mae: 0.1519 - val_mse: 0.0427 - val_root_mean_squared_error: 0.2067
# Epoch 187/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0620 - mae: 0.2045 - mse: 0.0620 - root_mean_squared_error: 0.2344 - val_loss: 0.0444 - val_mae: 0.1519 - val_mse: 0.0444 - val_root_mean_squared_error: 0.2107
# Epoch 188/200
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0619 - mae: 0.2007 - mse: 0.0619 - root_mean_squared_error: 0.2275 - val_loss: 0.0472 - val_mae: 0.1545 - val_mse: 0.0472 - val_root_mean_squared_error: 0.2172
# Epoch 189/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0635 - mae: 0.2033 - mse: 0.0635 - root_mean_squared_error: 0.2433 - val_loss: 0.0516 - val_mae: 0.1606 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2272
# Epoch 190/200
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0631 - mae: 0.2019 - mse: 0.0631 - root_mean_squared_error: 0.2547 - val_loss: 0.0558 - val_mae: 0.1677 - val_mse: 0.0558 - val_root_mean_squared_error: 0.2363
# Epoch 191/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0639 - mae: 0.2016 - mse: 0.0639 - root_mean_squared_error: 0.1873 - val_loss: 0.0581 - val_mae: 0.1725 - val_mse: 0.0581 - val_root_mean_squared_error: 0.2409
# Epoch 192/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0659 - mae: 0.2061 - mse: 0.0659 - root_mean_squared_error: 0.2401 - val_loss: 0.0580 - val_mae: 0.1729 - val_mse: 0.0580 - val_root_mean_squared_error: 0.2409
# Epoch 193/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0680 - mae: 0.2073 - mse: 0.0680 - root_mean_squared_error: 0.1986 - val_loss: 0.0558 - val_mae: 0.1693 - val_mse: 0.0558 - val_root_mean_squared_error: 0.2361
# Epoch 194/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0656 - mae: 0.2061 - mse: 0.0656 - root_mean_squared_error: 0.2080 - val_loss: 0.0509 - val_mae: 0.1601 - val_mse: 0.0509 - val_root_mean_squared_error: 0.2257
# Epoch 195/200
# 2/2 [==============================] - 0s 133ms/step - loss: 0.0646 - mae: 0.2044 - mse: 0.0646 - root_mean_squared_error: 0.2394 - val_loss: 0.0465 - val_mae: 0.1538 - val_mse: 0.0465 - val_root_mean_squared_error: 0.2156
# Epoch 196/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0615 - mae: 0.2026 - mse: 0.0615 - root_mean_squared_error: 0.3195 - val_loss: 0.0426 - val_mae: 0.1546 - val_mse: 0.0426 - val_root_mean_squared_error: 0.2064
# Epoch 197/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0622 - mae: 0.2007 - mse: 0.0622 - root_mean_squared_error: 0.2116 - val_loss: 0.0410 - val_mae: 0.1551 - val_mse: 0.0410 - val_root_mean_squared_error: 0.2026
# Epoch 198/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0647 - mae: 0.2087 - mse: 0.0647 - root_mean_squared_error: 0.2351 - val_loss: 0.0410 - val_mae: 0.1545 - val_mse: 0.0410 - val_root_mean_squared_error: 0.2025
# Epoch 199/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0634 - mae: 0.2043 - mse: 0.0634 - root_mean_squared_error: 0.2331 - val_loss: 0.0417 - val_mae: 0.1533 - val_mse: 0.0417 - val_root_mean_squared_error: 0.2042
# Epoch 200/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0646 - mae: 0.2068 - mse: 0.0646 - root_mean_squared_error: 0.2504 - val_loss: 0.0459 - val_mae: 0.1527 - val_mse: 0.0459 - val_root_mean_squared_error: 0.2143

# %%
# Evaluate on validation set
val_metrics_manul = manul_model.evaluate(val_data_inputs, val_data_targets, return_dict=True)

# Evaluate on test set
test_metrics_manul = manul_model.evaluate(test_data_inputs, test_data_targets, return_dict=True)

# Extract individual metrics
val_loss_manul, val_mae_manul, val_mse_manul, val_rmse_manul = val_metrics_manul['loss'], val_metrics_manul['mae'], val_metrics_manul['mse'], val_metrics_manul['root_mean_squared_error']
test_loss_manul, test_mae_manul, test_mse_manul, test_rmse_manul = test_metrics_manul['loss'], test_metrics_manul['mae'], test_metrics_manul['mse'], test_metrics_manul['root_mean_squared_error']

print('\n\nManual Transformer:\n-------------------')
print(f'Validation Loss: {val_loss_manul}, Validation MSE: {val_mse_manul}, Validation MAE: {val_mae_manul}, Validation RMSE: {val_rmse_manul}')
print(f'Test Loss: {test_loss_manul}, Test MSE: {test_mse_manul}, Test MAE: {test_mae_manul}, Test RMSE: {test_rmse_manul}')
# Out:
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0459 - mae: 0.1527 - mse: 0.0459 - root_mean_squared_error: 0.2143
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0339 - mae: 0.1736 - mse: 0.0339 - root_mean_squared_error: 0.1842
#
#
# Manual Transformer:
# -------------------
# Validation Loss: 0.04590541124343872, Validation MSE: 0.04590541124343872, Validation MAE: 0.1526624858379364, Validation RMSE: 0.21425548195838928
# Test Loss: 0.03392934426665306, Test MSE: 0.03392934426665306, Test MAE: 0.17364966869354248, Test RMSE: 0.18419919908046722

# %%
# Assuming manul_model.predict returns the predictions
val_predictions_manul = manul_model.predict(val_data_inputs)
test_predictions_manul = manul_model.predict(test_data_inputs)

# Calculate MAE and RMSE for validation set
val_mae_manul = np.mean(np.abs(val_data_targets - val_predictions_manul))
val_rmse_manul = np.sqrt(np.mean(np.square(val_data_targets - val_predictions_manul)))

# Calculate MAE and RMSE for test set
test_mae_manul = np.mean(np.abs(test_data_targets - test_predictions_manul))
test_rmse_manul = np.sqrt(np.mean(np.square(test_data_targets - test_predictions_manul)))

print('\n\nManual Transformer:\n-------------------')
print(f'Validation MAE: {val_mae_manul}')
print(f'Validation RMSE: {val_rmse_manul}')
print(f'\nTest MAE: {test_mae_manul}')
print(f'Test RMSE: {test_rmse_manul}')
print('\n==============================')
# Out:
# 1/1 [==============================] - 1s 991ms/step
# 1/1 [==============================] - 0s 31ms/step
#
#
# Manual Transformer:
# -------------------
# Validation MAE: 0.1547253578901291
# Validation RMSE: 0.2175816148519516
#
# Test MAE: 0.17318914630968676
# Test RMSE: 0.183777361300491
#
# ==============================
