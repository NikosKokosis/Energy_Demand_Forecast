# %%
import pandas as pd
import datetime as dt
import numpy as np
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

monthly = pd.read_csv('../Dataset/Boulder_Monthly.csv')
monthly.drop(columns={'Unnamed: 0'}, inplace=True)
monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Energy__kWh_   55 non-null     float64
#  1   Month          55 non-null     object
#  2   Minimum T      55 non-null     int64
#  3   Maximum T      55 non-null     int64
#  4   Snow           55 non-null     float64
#  5   Precipitation  55 non-null     float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 2.7+ KB

# %% [markdown]
#     Scale the Dataset with MinMaxScaler / One-Hot Encode and Extract the Entire Scaled Dataset

# %%
# Define the columns we need to scale and we need to use for One-Hot Encoding
columns_to_scale = ['Energy__kWh_', 'Minimum T', 'Maximum T', 'Snow', 'Precipitation']
categorical_columns = ['Month']

# MinMax scaling for numerical columns and One-hot encoding for categorical columns
scaler = MinMaxScaler()
monthly_scaled = monthly.copy()
monthly_scaled[columns_to_scale] = scaler.fit_transform(monthly[columns_to_scale])

# One-hot encoding for categorical columns
onehot_encoder = OneHotEncoder(sparse=False)
categorical_encoded = onehot_encoder.fit_transform(monthly[categorical_columns])

# Get the feature names from the encoder
encoded_columns = []
for col, values in zip(categorical_columns, onehot_encoder.categories_):
    encoded_columns.extend([f'{col}_{value}' for value in values])

# Create DataFrame with encoded columns
categorical_encoded_df = pd.DataFrame(categorical_encoded, columns=encoded_columns)

# Concatenate the new encoded columns to the original DataFrame
monthly_scaled = pd.concat([monthly_scaled, categorical_encoded_df], axis=1)

# Drop the original categorical columns
monthly_scaled = monthly_scaled.drop(categorical_columns, axis=1)
monthly_scaled.columns
# Out:
# Index(['Energy__kWh_', 'Minimum T', 'Maximum T', 'Snow', 'Precipitation',
#        'Month_April', 'Month_August', 'Month_December', 'Month_February',
#        'Month_January', 'Month_July', 'Month_June', 'Month_March', 'Month_May',
#        'Month_November', 'Month_October', 'Month_September'],
#       dtype='object')

# %% [markdown]
#     Divided the dataset into training, testing, and validation datasets according to 0.70, 0.20, and 0.10, respectively.

# %%
# Split the dataset into training, validation, and testing sets
def split_dataset(df, train_ratio, val_ratio):

    total_size = len(df)
    train_size = int(train_ratio * total_size)
    val_size = int(val_ratio * total_size)
    test_size = total_size - train_size - val_size

    train_df = df[:train_size]
    val_df = df[train_size:train_size + val_size]
    test_df = df[train_size + val_size:]

    assert len(train_df) + len(val_df) + len(test_df) == total_size, "Dataset not split correctly."

    print(f'Training split ratio:   {round(len(train_df) / len(df), 3)}')
    print(f'Validation split ratio: {round(len(val_df) / len(df), 3)}')
    print(f'Testing split ratio:    {round(len(test_df) / len(df), 3)}')
    print("\nShapes of the datasets:")
    print(train_df.shape, val_df.shape, test_df.shape)

    return train_df, val_df, test_df

# %%
train_monthly_scaled, val_monthly_scaled, test_monthly_scaled = split_dataset(monthly_scaled, train_ratio=0.7, val_ratio=0.2)
# Out:
# Training split ratio:   0.691
# Validation split ratio: 0.2
# Testing split ratio:    0.109
#
# Shapes of the datasets:
# (38, 17) (11, 17) (6, 17)

# %% [markdown]
#     Create sequences for the Transformer model

# %%
# Reshape the data
def create_sequences(data, sequence_length):
    inputs = []
    targets = []
    for i in range(len(data) - sequence_length):
        sequence = data.iloc[i:i + sequence_length].values
        target = data.iloc[i + sequence_length]['Energy__kWh_']  # Predict the next value
        inputs.append(sequence)
        targets.append(target)

    inputs_array = np.array(inputs)
    targets_array = np.array(targets)
    
    print(f'Dataset split into sequences:')
    print(f'Sequences shape: {inputs_array.shape}')
    print(f'Targets shape: {targets_array.shape}\n')

    return np.array(inputs), np.array(targets)

# %%
sequence_length = 3
num_features = len(monthly_scaled.columns)

# Create the training, validation, and test data sequences
train_data_inputs, train_data_targets = create_sequences(train_monthly_scaled, sequence_length)
val_data_inputs, val_data_targets = create_sequences(val_monthly_scaled, sequence_length)
test_data_inputs, test_data_targets = create_sequences(test_monthly_scaled, sequence_length)
# Out:
# Dataset split into sequences:
# Sequences shape: (35, 3, 17)
# Targets shape: (35,)
#
# Dataset split into sequences:
# Sequences shape: (8, 3, 17)
# Targets shape: (8,)
#
# Dataset split into sequences:
# Sequences shape: (3, 3, 17)
# Targets shape: (3,)

# %%
# The input Datasets must have this input shape (-1, sequence_length, num_features)
train_data_inputs = train_data_inputs.reshape((-1, sequence_length, num_features))
val_data_inputs = val_data_inputs.reshape((-1, sequence_length, num_features))
test_data_inputs = test_data_inputs.reshape((-1, sequence_length, num_features))

train_data_inputs.shape, val_data_inputs.shape, test_data_inputs.shape
# Out:
# ((36, 2, 17), (9, 2, 17), (4, 2, 17))

# %% [markdown]
#     Create the Transformer Models

# %%
# %run "../Code/Transformer.ipynb"

# Define the hyperparameters of the manual model
input_shape = (sequence_length, num_features)
num_heads = 1
d_ff = 64
num_layers = 3
dropout_rate = 0.1
encoder_mask = None
decoder_mask = tf.linalg.band_part(tf.ones((sequence_length, sequence_length)), -1, 0)  # Create a lower triangular mask
decoder_mask = 1 - decoder_mask  # Invert the mask

# Create the transformer model
manul_model = TransformerModel(input_shape, num_heads, d_ff, num_layers, dropout_rate, encoder_mask, decoder_mask)

manul_model.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_11 (InputLayer)          [(None, 2, 17)]      0           []
#
#  multi_head_attention_92 (Multi  (None, None, 17)    1224        ['input_11[0][0]',
#  HeadAttention)                                                   'input_11[0][0]',
#                                                                   'input_11[0][0]']
#
#  dropout_186 (Dropout)          (None, None, 17)     0           ['multi_head_attention_92[0][0]']
#
#  tf.__operators__.add_79 (TFOpL  (None, 2, 17)       0           ['input_11[0][0]',
#  ambda)                                                           'dropout_186[0][0]']
#
#  layer_normalization_154 (Layer  (None, 2, 17)       34          ['tf.__operators__.add_79[0][0]']
#  Normalization)
#
#  positionwise_feed_forward_32 (  (None, 2, 17)       2257        ['layer_normalization_154[0][0]']
#  PositionwiseFeedForward)
#
#  dropout_188 (Dropout)          (None, 2, 17)        0           ['positionwise_feed_forward_32[0]
#                                                                  [0]']
#
#  tf.__operators__.add_80 (TFOpL  (None, 2, 17)       0           ['layer_normalization_154[0][0]',
#  ambda)                                                           'dropout_188[0][0]']
#
#  layer_normalization_155 (Layer  (None, 2, 17)       34          ['tf.__operators__.add_80[0][0]']
#  Normalization)
#
#  multi_head_attention_97 (Multi  (None, None, 17)    1224        ['layer_normalization_155[0][0]',
#  HeadAttention)                                                   'layer_normalization_155[0][0]',
#                                                                   'layer_normalization_155[0][0]']
#
#  dropout_197 (Dropout)          (None, None, 17)     0           ['multi_head_attention_97[0][0]']
#
#  tf.__operators__.add_87 (TFOpL  (None, 2, 17)       0           ['dropout_197[0][0]',
#  ambda)                                                           'layer_normalization_155[0][0]']
#
#  layer_normalization_162 (Layer  (None, 2, 17)       34          ['tf.__operators__.add_87[0][0]']
#  Normalization)
#
#  multi_head_attention_98 (Multi  (None, None, 17)    1224        ['layer_normalization_162[0][0]',
#  HeadAttention)                                                   'input_11[0][0]',
#                                                                   'input_11[0][0]']
#
#  dropout_198 (Dropout)          (None, None, 17)     0           ['multi_head_attention_98[0][0]']
#
#  tf.__operators__.add_88 (TFOpL  (None, None, 17)    0           ['dropout_197[0][0]',
#  ambda)                                                           'dropout_198[0][0]']
#
#  layer_normalization_163 (Layer  (None, None, 17)    34          ['tf.__operators__.add_88[0][0]']
#  Normalization)
#
#  positionwise_feed_forward_35 (  (None, None, 17)    2257        ['layer_normalization_163[0][0]']
#  PositionwiseFeedForward)
#
#  dropout_200 (Dropout)          (None, None, 17)     0           ['positionwise_feed_forward_35[0]
#                                                                  [0]']
#
#  tf.__operators__.add_89 (TFOpL  (None, None, 17)    0           ['layer_normalization_163[0][0]',
#  ambda)                                                           'dropout_200[0][0]']
#
#  layer_normalization_164 (Layer  (None, None, 17)    34          ['tf.__operators__.add_89[0][0]']
#  Normalization)
#
#  time_distributed_10 (TimeDistr  (None, None, 1)     18          ['layer_normalization_164[0][0]']
#  ibuted)
#
# ==================================================================================================
# Total params: 8,374
# Trainable params: 8,374
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Create the transformer model
keras_model = keras_transformer_model(input_shape, num_heads, d_ff, num_layers, dropout_rate)

keras_model.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 2, 17)]      0           []
#
#  multi_head_attention_99 (Multi  (None, 2, 17)       159         ['input_12[0][0]',
#  HeadAttention)                                                   'input_12[0][0]']
#
#  dropout_201 (Dropout)          (None, 2, 17)        0           ['multi_head_attention_99[0][0]']
#
#  layer_normalization_165 (Layer  (None, 2, 17)       34          ['dropout_201[0][0]']
#  Normalization)
#
#  sequential_66 (Sequential)     (None, 2, 2)         1282        ['layer_normalization_165[0][0]']
#
#  dropout_202 (Dropout)          (None, 2, 2)         0           ['sequential_66[0][0]']
#
#  layer_normalization_166 (Layer  (None, 2, 2)        4           ['dropout_202[0][0]']
#  Normalization)
#
#  multi_head_attention_100 (Mult  (None, 2, 2)        24          ['layer_normalization_166[0][0]',
#  iHeadAttention)                                                  'layer_normalization_166[0][0]']
#
#  dropout_203 (Dropout)          (None, 2, 2)         0           ['multi_head_attention_100[0][0]'
#                                                                  ]
#
#  layer_normalization_167 (Layer  (None, 2, 2)        4           ['dropout_203[0][0]']
#  Normalization)
#
#  sequential_67 (Sequential)     (None, 2, 2)         322         ['layer_normalization_167[0][0]']
#
#  dropout_204 (Dropout)          (None, 2, 2)         0           ['sequential_67[0][0]']
#
#  layer_normalization_168 (Layer  (None, 2, 2)        4           ['dropout_204[0][0]']
#  Normalization)
#
#  multi_head_attention_101 (Mult  (None, 2, 2)        24          ['layer_normalization_168[0][0]',
#  iHeadAttention)                                                  'layer_normalization_168[0][0]']
#
#  dropout_205 (Dropout)          (None, 2, 2)         0           ['multi_head_attention_101[0][0]'
#                                                                  ]
#
#  layer_normalization_169 (Layer  (None, 2, 2)        4           ['dropout_205[0][0]']
#  Normalization)
#
#  sequential_68 (Sequential)     (None, 2, 2)         322         ['layer_normalization_169[0][0]']
#
#  dropout_206 (Dropout)          (None, 2, 2)         0           ['sequential_68[0][0]']
#
#  layer_normalization_170 (Layer  (None, 2, 2)        4           ['dropout_206[0][0]']
#  Normalization)
#
#  multi_head_attention_102 (Mult  (None, 2, 2)        24          ['layer_normalization_170[0][0]',
#  iHeadAttention)                                                  'layer_normalization_170[0][0]']
#
#  dropout_207 (Dropout)          (None, 2, 2)         0           ['multi_head_attention_102[0][0]'
#                                                                  ]
#
#  layer_normalization_171 (Layer  (None, 2, 2)        4           ['dropout_207[0][0]']
#  Normalization)
#
#  multi_head_attention_103 (Mult  (None, 2, 2)        24          ['layer_normalization_171[0][0]',
#  iHeadAttention)                                                  'layer_normalization_170[0][0]']
#
#  dropout_208 (Dropout)          (None, 2, 2)         0           ['multi_head_attention_103[0][0]'
#                                                                  ]
#
#  layer_normalization_172 (Layer  (None, 2, 2)        4           ['dropout_208[0][0]']
#  Normalization)
#
#  sequential_69 (Sequential)     (None, 2, 2)         322         ['layer_normalization_172[0][0]']
#
#  dropout_209 (Dropout)          (None, 2, 2)         0           ['sequential_69[0][0]']
#
#  layer_normalization_173 (Layer  (None, 2, 2)        4           ['dropout_209[0][0]']
#  Normalization)
#
#  multi_head_attention_104 (Mult  (None, 2, 2)        24          ['layer_normalization_173[0][0]',
#  iHeadAttention)                                                  'layer_normalization_173[0][0]']
#
#  dropout_210 (Dropout)          (None, 2, 2)         0           ['multi_head_attention_104[0][0]'
#                                                                  ]
#
#  layer_normalization_174 (Layer  (None, 2, 2)        4           ['dropout_210[0][0]']
#  Normalization)
#
#  multi_head_attention_105 (Mult  (None, 2, 2)        24          ['layer_normalization_174[0][0]',
#  iHeadAttention)                                                  'layer_normalization_170[0][0]']
#
#  dropout_211 (Dropout)          (None, 2, 2)         0           ['multi_head_attention_105[0][0]'
#                                                                  ]
#
#  layer_normalization_175 (Layer  (None, 2, 2)        4           ['dropout_211[0][0]']
#  Normalization)
#
#  sequential_70 (Sequential)     (None, 2, 2)         322         ['layer_normalization_175[0][0]']
#
#  dropout_212 (Dropout)          (None, 2, 2)         0           ['sequential_70[0][0]']
#
#  layer_normalization_176 (Layer  (None, 2, 2)        4           ['dropout_212[0][0]']
#  Normalization)
#
#  multi_head_attention_106 (Mult  (None, 2, 2)        24          ['layer_normalization_176[0][0]',
#  iHeadAttention)                                                  'layer_normalization_176[0][0]']
#
#  dropout_213 (Dropout)          (None, 2, 2)         0           ['multi_head_attention_106[0][0]'
#                                                                  ]
#
#  layer_normalization_177 (Layer  (None, 2, 2)        4           ['dropout_213[0][0]']
#  Normalization)
#
#  multi_head_attention_107 (Mult  (None, 2, 2)        24          ['layer_normalization_177[0][0]',
#  iHeadAttention)                                                  'layer_normalization_170[0][0]']
#
#  dropout_214 (Dropout)          (None, 2, 2)         0           ['multi_head_attention_107[0][0]'
#                                                                  ]
#
#  layer_normalization_178 (Layer  (None, 2, 2)        4           ['dropout_214[0][0]']
#  Normalization)
#
#  sequential_71 (Sequential)     (None, 2, 2)         322         ['layer_normalization_178[0][0]']
#
#  dropout_215 (Dropout)          (None, 2, 2)         0           ['sequential_71[0][0]']
#
#  layer_normalization_179 (Layer  (None, 2, 2)        4           ['dropout_215[0][0]']
#  Normalization)
#
#  time_distributed_11 (TimeDistr  (None, 2, 1)        3           ['layer_normalization_179[0][0]']
#  ibuted)
#
# ==================================================================================================
# Total params: 3,336
# Trainable params: 3,336
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
#     Compile the Models

# %%
def root_mean_squared_error(y_true, y_pred):
    return tf.keras.backend.sqrt(
        tf.keras.backend.mean(
            tf.keras.backend.square(
                y_pred - y_true
            )
        ) + 1e-9
    )

# %%
# Define the learning rate for Adam optimizer
learning_rate = 0.01

# Compile the manual model
manul_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate), loss='mse',  metrics=['mae', 'mse', root_mean_squared_error])

# Compile the keras model
keras_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate), loss='mse',  metrics=['mae', 'mse', root_mean_squared_error])

# %% [markdown]
#     Train the Models

# %%
# Define the parameters for training
epochs = 200
batch_size = 32

# Convert the data to float32
train_data_inputs = train_data_inputs.astype('float32')
train_data_targets = train_data_targets.astype('float32')

val_data_inputs = val_data_inputs.astype('float32')
val_data_targets = val_data_targets.astype('float32')

train_data_inputs.shape, train_data_targets.shape, val_data_inputs.shape, val_data_targets.shape
# Out:
# ((36, 2, 17), (36,), (9, 2, 17), (9,))

# %%
# Train the manual model
manul_model.fit(train_data_inputs, train_data_targets,
          validation_data=(val_data_inputs, val_data_targets),
          epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/200
# 2/2 [==============================] - 5s 962ms/step - loss: 0.5505 - mae: 0.6119 - mse: 0.5505 - root_mean_squared_error: 0.8014 - val_loss: 0.1704 - val_mae: 0.3651 - val_mse: 0.1704 - val_root_mean_squared_error: 0.4128
# Epoch 2/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6663 - mae: 0.6601 - mse: 0.6663 - root_mean_squared_error: 0.7608 - val_loss: 0.3692 - val_mae: 0.5355 - val_mse: 0.3692 - val_root_mean_squared_error: 0.6076
# Epoch 3/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.5490 - mae: 0.6004 - mse: 0.5490 - root_mean_squared_error: 0.7699 - val_loss: 0.0999 - val_mae: 0.2698 - val_mse: 0.0999 - val_root_mean_squared_error: 0.3160
# Epoch 4/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1631 - mae: 0.3283 - mse: 0.1631 - root_mean_squared_error: 0.4549 - val_loss: 0.3824 - val_mae: 0.5725 - val_mse: 0.3824 - val_root_mean_squared_error: 0.6184
# Epoch 5/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.3521 - mae: 0.5069 - mse: 0.3521 - root_mean_squared_error: 0.5016 - val_loss: 0.1540 - val_mae: 0.3538 - val_mse: 0.1540 - val_root_mean_squared_error: 0.3925
# Epoch 6/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1671 - mae: 0.3352 - mse: 0.1671 - root_mean_squared_error: 0.3795 - val_loss: 0.0543 - val_mae: 0.1752 - val_mse: 0.0543 - val_root_mean_squared_error: 0.2331
# Epoch 7/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1527 - mae: 0.3083 - mse: 0.1527 - root_mean_squared_error: 0.4311 - val_loss: 0.1022 - val_mae: 0.2562 - val_mse: 0.1022 - val_root_mean_squared_error: 0.3198
# Epoch 8/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2130 - mae: 0.3731 - mse: 0.2130 - root_mean_squared_error: 0.4478 - val_loss: 0.0648 - val_mae: 0.1950 - val_mse: 0.0648 - val_root_mean_squared_error: 0.2545
# Epoch 9/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1315 - mae: 0.2856 - mse: 0.1315 - root_mean_squared_error: 0.3488 - val_loss: 0.0684 - val_mae: 0.2139 - val_mse: 0.0684 - val_root_mean_squared_error: 0.2615
# Epoch 10/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1048 - mae: 0.2693 - mse: 0.1048 - root_mean_squared_error: 0.3402 - val_loss: 0.1128 - val_mae: 0.2999 - val_mse: 0.1128 - val_root_mean_squared_error: 0.3359
# Epoch 11/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1435 - mae: 0.3155 - mse: 0.1435 - root_mean_squared_error: 0.4489 - val_loss: 0.0755 - val_mae: 0.2293 - val_mse: 0.0755 - val_root_mean_squared_error: 0.2748
# Epoch 12/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1159 - mae: 0.2837 - mse: 0.1159 - root_mean_squared_error: 0.2698 - val_loss: 0.0526 - val_mae: 0.1723 - val_mse: 0.0526 - val_root_mean_squared_error: 0.2294
# Epoch 13/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0946 - mae: 0.2428 - mse: 0.0946 - root_mean_squared_error: 0.2800 - val_loss: 0.0685 - val_mae: 0.2031 - val_mse: 0.0685 - val_root_mean_squared_error: 0.2617
# Epoch 14/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1138 - mae: 0.2622 - mse: 0.1138 - root_mean_squared_error: 0.3293 - val_loss: 0.0689 - val_mae: 0.2038 - val_mse: 0.0689 - val_root_mean_squared_error: 0.2624
# Epoch 15/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1113 - mae: 0.2605 - mse: 0.1113 - root_mean_squared_error: 0.3218 - val_loss: 0.0537 - val_mae: 0.1732 - val_mse: 0.0537 - val_root_mean_squared_error: 0.2318
# Epoch 16/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1018 - mae: 0.2555 - mse: 0.1018 - root_mean_squared_error: 0.3318 - val_loss: 0.0543 - val_mae: 0.1801 - val_mse: 0.0543 - val_root_mean_squared_error: 0.2330
# Epoch 17/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0922 - mae: 0.2440 - mse: 0.0922 - root_mean_squared_error: 0.2808 - val_loss: 0.0565 - val_mae: 0.1848 - val_mse: 0.0565 - val_root_mean_squared_error: 0.2377
# Epoch 18/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0921 - mae: 0.2457 - mse: 0.0921 - root_mean_squared_error: 0.3053 - val_loss: 0.0553 - val_mae: 0.1821 - val_mse: 0.0553 - val_root_mean_squared_error: 0.2351
# Epoch 19/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0844 - mae: 0.2374 - mse: 0.0844 - root_mean_squared_error: 0.2303 - val_loss: 0.0535 - val_mae: 0.1782 - val_mse: 0.0535 - val_root_mean_squared_error: 0.2312
# Epoch 20/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0831 - mae: 0.2378 - mse: 0.0831 - root_mean_squared_error: 0.3268 - val_loss: 0.0521 - val_mae: 0.1754 - val_mse: 0.0521 - val_root_mean_squared_error: 0.2284
# Epoch 21/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0847 - mae: 0.2362 - mse: 0.0847 - root_mean_squared_error: 0.2641 - val_loss: 0.0518 - val_mae: 0.1736 - val_mse: 0.0518 - val_root_mean_squared_error: 0.2275
# Epoch 22/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0762 - mae: 0.2237 - mse: 0.0762 - root_mean_squared_error: 0.2551 - val_loss: 0.0518 - val_mae: 0.1725 - val_mse: 0.0518 - val_root_mean_squared_error: 0.2277
# Epoch 23/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0840 - mae: 0.2323 - mse: 0.0840 - root_mean_squared_error: 0.2550 - val_loss: 0.0535 - val_mae: 0.1727 - val_mse: 0.0535 - val_root_mean_squared_error: 0.2313
# Epoch 24/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0851 - mae: 0.2305 - mse: 0.0851 - root_mean_squared_error: 0.2531 - val_loss: 0.0533 - val_mae: 0.1725 - val_mse: 0.0533 - val_root_mean_squared_error: 0.2308
# Epoch 25/200
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0849 - mae: 0.2305 - mse: 0.0849 - root_mean_squared_error: 0.2753 - val_loss: 0.0522 - val_mae: 0.1757 - val_mse: 0.0522 - val_root_mean_squared_error: 0.2285
# Epoch 26/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0794 - mae: 0.2282 - mse: 0.0794 - root_mean_squared_error: 0.3187 - val_loss: 0.0645 - val_mae: 0.2049 - val_mse: 0.0645 - val_root_mean_squared_error: 0.2540
# Epoch 27/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0871 - mae: 0.2465 - mse: 0.0871 - root_mean_squared_error: 0.3256 - val_loss: 0.0745 - val_mae: 0.2271 - val_mse: 0.0745 - val_root_mean_squared_error: 0.2729
# Epoch 28/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0890 - mae: 0.2488 - mse: 0.0890 - root_mean_squared_error: 0.2600 - val_loss: 0.0612 - val_mae: 0.1968 - val_mse: 0.0612 - val_root_mean_squared_error: 0.2474
# Epoch 29/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0795 - mae: 0.2317 - mse: 0.0795 - root_mean_squared_error: 0.2880 - val_loss: 0.0520 - val_mae: 0.1749 - val_mse: 0.0520 - val_root_mean_squared_error: 0.2280
# Epoch 30/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0810 - mae: 0.2286 - mse: 0.0810 - root_mean_squared_error: 0.3423 - val_loss: 0.0517 - val_mae: 0.1728 - val_mse: 0.0517 - val_root_mean_squared_error: 0.2274
# Epoch 31/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0754 - mae: 0.2217 - mse: 0.0754 - root_mean_squared_error: 0.2392 - val_loss: 0.0521 - val_mae: 0.1755 - val_mse: 0.0521 - val_root_mean_squared_error: 0.2283
# Epoch 32/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0785 - mae: 0.2277 - mse: 0.0785 - root_mean_squared_error: 0.2577 - val_loss: 0.0533 - val_mae: 0.1778 - val_mse: 0.0533 - val_root_mean_squared_error: 0.2309
# Epoch 33/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0785 - mae: 0.2262 - mse: 0.0785 - root_mean_squared_error: 0.2762 - val_loss: 0.0558 - val_mae: 0.1831 - val_mse: 0.0558 - val_root_mean_squared_error: 0.2363
# Epoch 34/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0763 - mae: 0.2282 - mse: 0.0763 - root_mean_squared_error: 0.2436 - val_loss: 0.0528 - val_mae: 0.1769 - val_mse: 0.0528 - val_root_mean_squared_error: 0.2298
# Epoch 35/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0756 - mae: 0.2269 - mse: 0.0756 - root_mean_squared_error: 0.2811 - val_loss: 0.0542 - val_mae: 0.1735 - val_mse: 0.0542 - val_root_mean_squared_error: 0.2328
# Epoch 36/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0787 - mae: 0.2224 - mse: 0.0787 - root_mean_squared_error: 0.2134 - val_loss: 0.0707 - val_mae: 0.2080 - val_mse: 0.0707 - val_root_mean_squared_error: 0.2660
# Epoch 37/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0957 - mae: 0.2384 - mse: 0.0957 - root_mean_squared_error: 0.3162 - val_loss: 0.0716 - val_mae: 0.2098 - val_mse: 0.0716 - val_root_mean_squared_error: 0.2676
# Epoch 38/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0948 - mae: 0.2353 - mse: 0.0948 - root_mean_squared_error: 0.2505 - val_loss: 0.0543 - val_mae: 0.1737 - val_mse: 0.0543 - val_root_mean_squared_error: 0.2331
# Epoch 39/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0748 - mae: 0.2218 - mse: 0.0748 - root_mean_squared_error: 0.2829 - val_loss: 0.0543 - val_mae: 0.1801 - val_mse: 0.0543 - val_root_mean_squared_error: 0.2330
# Epoch 40/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0734 - mae: 0.2236 - mse: 0.0734 - root_mean_squared_error: 0.2481 - val_loss: 0.0680 - val_mae: 0.2128 - val_mse: 0.0680 - val_root_mean_squared_error: 0.2607
# Epoch 41/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0853 - mae: 0.2454 - mse: 0.0853 - root_mean_squared_error: 0.3141 - val_loss: 0.0725 - val_mae: 0.2230 - val_mse: 0.0725 - val_root_mean_squared_error: 0.2693
# Epoch 42/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0878 - mae: 0.2496 - mse: 0.0878 - root_mean_squared_error: 0.2890 - val_loss: 0.0573 - val_mae: 0.1869 - val_mse: 0.0573 - val_root_mean_squared_error: 0.2395
# Epoch 43/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0778 - mae: 0.2303 - mse: 0.0778 - root_mean_squared_error: 0.3075 - val_loss: 0.0521 - val_mae: 0.1723 - val_mse: 0.0521 - val_root_mean_squared_error: 0.2283
# Epoch 44/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0737 - mae: 0.2191 - mse: 0.0737 - root_mean_squared_error: 0.2218 - val_loss: 0.0581 - val_mae: 0.1799 - val_mse: 0.0581 - val_root_mean_squared_error: 0.2411
# Epoch 45/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0795 - mae: 0.2240 - mse: 0.0795 - root_mean_squared_error: 0.2633 - val_loss: 0.0614 - val_mae: 0.1872 - val_mse: 0.0614 - val_root_mean_squared_error: 0.2478
# Epoch 46/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0830 - mae: 0.2262 - mse: 0.0830 - root_mean_squared_error: 0.2578 - val_loss: 0.0537 - val_mae: 0.1729 - val_mse: 0.0537 - val_root_mean_squared_error: 0.2317
# Epoch 47/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0757 - mae: 0.2199 - mse: 0.0757 - root_mean_squared_error: 0.2566 - val_loss: 0.0526 - val_mae: 0.1769 - val_mse: 0.0526 - val_root_mean_squared_error: 0.2294
# Epoch 48/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0706 - mae: 0.2178 - mse: 0.0706 - root_mean_squared_error: 0.2651 - val_loss: 0.0596 - val_mae: 0.1925 - val_mse: 0.0596 - val_root_mean_squared_error: 0.2442
# Epoch 49/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0782 - mae: 0.2321 - mse: 0.0782 - root_mean_squared_error: 0.2983 - val_loss: 0.0558 - val_mae: 0.1830 - val_mse: 0.0558 - val_root_mean_squared_error: 0.2363
# Epoch 50/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0751 - mae: 0.2273 - mse: 0.0751 - root_mean_squared_error: 0.2781 - val_loss: 0.0517 - val_mae: 0.1722 - val_mse: 0.0517 - val_root_mean_squared_error: 0.2275
# Epoch 51/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0708 - mae: 0.2164 - mse: 0.0708 - root_mean_squared_error: 0.2393 - val_loss: 0.0553 - val_mae: 0.1750 - val_mse: 0.0553 - val_root_mean_squared_error: 0.2351
# Epoch 52/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0768 - mae: 0.2198 - mse: 0.0768 - root_mean_squared_error: 0.2459 - val_loss: 0.0608 - val_mae: 0.1857 - val_mse: 0.0608 - val_root_mean_squared_error: 0.2465
# Epoch 53/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0811 - mae: 0.2246 - mse: 0.0811 - root_mean_squared_error: 0.2437 - val_loss: 0.0607 - val_mae: 0.1856 - val_mse: 0.0607 - val_root_mean_squared_error: 0.2465
# Epoch 54/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0868 - mae: 0.2307 - mse: 0.0868 - root_mean_squared_error: 0.3098 - val_loss: 0.0532 - val_mae: 0.1725 - val_mse: 0.0532 - val_root_mean_squared_error: 0.2307
# Epoch 55/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0749 - mae: 0.2195 - mse: 0.0749 - root_mean_squared_error: 0.3389 - val_loss: 0.0520 - val_mae: 0.1752 - val_mse: 0.0520 - val_root_mean_squared_error: 0.2281
# Epoch 56/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0694 - mae: 0.2169 - mse: 0.0694 - root_mean_squared_error: 0.2885 - val_loss: 0.0558 - val_mae: 0.1831 - val_mse: 0.0558 - val_root_mean_squared_error: 0.2363
# Epoch 57/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0725 - mae: 0.2224 - mse: 0.0725 - root_mean_squared_error: 0.2032 - val_loss: 0.0607 - val_mae: 0.1953 - val_mse: 0.0607 - val_root_mean_squared_error: 0.2463
# Epoch 58/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0809 - mae: 0.2383 - mse: 0.0809 - root_mean_squared_error: 0.2480 - val_loss: 0.0561 - val_mae: 0.1837 - val_mse: 0.0561 - val_root_mean_squared_error: 0.2369
# Epoch 59/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0784 - mae: 0.2325 - mse: 0.0784 - root_mean_squared_error: 0.2641 - val_loss: 0.0518 - val_mae: 0.1745 - val_mse: 0.0518 - val_root_mean_squared_error: 0.2277
# Epoch 60/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0742 - mae: 0.2211 - mse: 0.0742 - root_mean_squared_error: 0.3316 - val_loss: 0.0517 - val_mae: 0.1733 - val_mse: 0.0517 - val_root_mean_squared_error: 0.2273
# Epoch 61/200
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0715 - mae: 0.2184 - mse: 0.0715 - root_mean_squared_error: 0.2698 - val_loss: 0.0517 - val_mae: 0.1742 - val_mse: 0.0517 - val_root_mean_squared_error: 0.2274
# Epoch 62/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0701 - mae: 0.2181 - mse: 0.0701 - root_mean_squared_error: 0.2870 - val_loss: 0.0529 - val_mae: 0.1723 - val_mse: 0.0529 - val_root_mean_squared_error: 0.2301
# Epoch 63/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0720 - mae: 0.2197 - mse: 0.0720 - root_mean_squared_error: 0.2602 - val_loss: 0.0581 - val_mae: 0.1798 - val_mse: 0.0581 - val_root_mean_squared_error: 0.2411
# Epoch 64/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0752 - mae: 0.2197 - mse: 0.0752 - root_mean_squared_error: 0.2372 - val_loss: 0.0564 - val_mae: 0.1767 - val_mse: 0.0564 - val_root_mean_squared_error: 0.2374
# Epoch 65/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0751 - mae: 0.2179 - mse: 0.0751 - root_mean_squared_error: 0.2462 - val_loss: 0.0525 - val_mae: 0.1721 - val_mse: 0.0525 - val_root_mean_squared_error: 0.2290
# Epoch 66/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0708 - mae: 0.2166 - mse: 0.0708 - root_mean_squared_error: 0.3127 - val_loss: 0.0520 - val_mae: 0.1754 - val_mse: 0.0520 - val_root_mean_squared_error: 0.2281
# Epoch 67/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0692 - mae: 0.2159 - mse: 0.0692 - root_mean_squared_error: 0.3050 - val_loss: 0.0584 - val_mae: 0.1896 - val_mse: 0.0584 - val_root_mean_squared_error: 0.2417
# Epoch 68/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0755 - mae: 0.2287 - mse: 0.0755 - root_mean_squared_error: 0.2533 - val_loss: 0.0628 - val_mae: 0.2009 - val_mse: 0.0628 - val_root_mean_squared_error: 0.2507
# Epoch 69/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0791 - mae: 0.2350 - mse: 0.0791 - root_mean_squared_error: 0.2786 - val_loss: 0.0546 - val_mae: 0.1805 - val_mse: 0.0546 - val_root_mean_squared_error: 0.2336
# Epoch 70/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0717 - mae: 0.2207 - mse: 0.0717 - root_mean_squared_error: 0.2530 - val_loss: 0.0516 - val_mae: 0.1726 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2272
# Epoch 71/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0705 - mae: 0.2161 - mse: 0.0705 - root_mean_squared_error: 0.2622 - val_loss: 0.0522 - val_mae: 0.1719 - val_mse: 0.0522 - val_root_mean_squared_error: 0.2285
# Epoch 72/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0699 - mae: 0.2157 - mse: 0.0699 - root_mean_squared_error: 0.3021 - val_loss: 0.0517 - val_mae: 0.1724 - val_mse: 0.0517 - val_root_mean_squared_error: 0.2273
# Epoch 73/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0685 - mae: 0.2141 - mse: 0.0685 - root_mean_squared_error: 0.2609 - val_loss: 0.0517 - val_mae: 0.1723 - val_mse: 0.0517 - val_root_mean_squared_error: 0.2273
# Epoch 74/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0693 - mae: 0.2151 - mse: 0.0693 - root_mean_squared_error: 0.2912 - val_loss: 0.0520 - val_mae: 0.1719 - val_mse: 0.0520 - val_root_mean_squared_error: 0.2280
# Epoch 75/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0710 - mae: 0.2161 - mse: 0.0710 - root_mean_squared_error: 0.2603 - val_loss: 0.0518 - val_mae: 0.1748 - val_mse: 0.0518 - val_root_mean_squared_error: 0.2276
# Epoch 76/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0720 - mae: 0.2210 - mse: 0.0720 - root_mean_squared_error: 0.2774 - val_loss: 0.0517 - val_mae: 0.1741 - val_mse: 0.0517 - val_root_mean_squared_error: 0.2273
# Epoch 77/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0695 - mae: 0.2160 - mse: 0.0695 - root_mean_squared_error: 0.2028 - val_loss: 0.0533 - val_mae: 0.1725 - val_mse: 0.0533 - val_root_mean_squared_error: 0.2309
# Epoch 78/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0760 - mae: 0.2219 - mse: 0.0760 - root_mean_squared_error: 0.2548 - val_loss: 0.0575 - val_mae: 0.1783 - val_mse: 0.0575 - val_root_mean_squared_error: 0.2397
# Epoch 79/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0769 - mae: 0.2241 - mse: 0.0769 - root_mean_squared_error: 0.2532 - val_loss: 0.0556 - val_mae: 0.1753 - val_mse: 0.0556 - val_root_mean_squared_error: 0.2358
# Epoch 80/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0749 - mae: 0.2188 - mse: 0.0749 - root_mean_squared_error: 0.2368 - val_loss: 0.0516 - val_mae: 0.1732 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2271
# Epoch 81/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0699 - mae: 0.2171 - mse: 0.0699 - root_mean_squared_error: 0.2312 - val_loss: 0.0522 - val_mae: 0.1760 - val_mse: 0.0522 - val_root_mean_squared_error: 0.2285
# Epoch 82/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0702 - mae: 0.2165 - mse: 0.0702 - root_mean_squared_error: 0.2425 - val_loss: 0.0516 - val_mae: 0.1732 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2271
# Epoch 83/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0715 - mae: 0.2182 - mse: 0.0715 - root_mean_squared_error: 0.2729 - val_loss: 0.0518 - val_mae: 0.1719 - val_mse: 0.0518 - val_root_mean_squared_error: 0.2277
# Epoch 84/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0713 - mae: 0.2169 - mse: 0.0713 - root_mean_squared_error: 0.2562 - val_loss: 0.0521 - val_mae: 0.1719 - val_mse: 0.0521 - val_root_mean_squared_error: 0.2282
# Epoch 85/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0700 - mae: 0.2162 - mse: 0.0700 - root_mean_squared_error: 0.2585 - val_loss: 0.0524 - val_mae: 0.1719 - val_mse: 0.0524 - val_root_mean_squared_error: 0.2289
# Epoch 86/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0704 - mae: 0.2152 - mse: 0.0704 - root_mean_squared_error: 0.1889 - val_loss: 0.0516 - val_mae: 0.1734 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2271
# Epoch 87/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0689 - mae: 0.2148 - mse: 0.0689 - root_mean_squared_error: 0.2660 - val_loss: 0.0523 - val_mae: 0.1762 - val_mse: 0.0523 - val_root_mean_squared_error: 0.2287
# Epoch 88/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0701 - mae: 0.2177 - mse: 0.0701 - root_mean_squared_error: 0.3056 - val_loss: 0.0535 - val_mae: 0.1783 - val_mse: 0.0535 - val_root_mean_squared_error: 0.2313
# Epoch 89/200
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0705 - mae: 0.2194 - mse: 0.0705 - root_mean_squared_error: 0.2558 - val_loss: 0.0532 - val_mae: 0.1776 - val_mse: 0.0532 - val_root_mean_squared_error: 0.2306
# Epoch 90/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0709 - mae: 0.2198 - mse: 0.0709 - root_mean_squared_error: 0.2293 - val_loss: 0.0525 - val_mae: 0.1766 - val_mse: 0.0525 - val_root_mean_squared_error: 0.2292
# Epoch 91/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0709 - mae: 0.2173 - mse: 0.0709 - root_mean_squared_error: 0.2698 - val_loss: 0.0516 - val_mae: 0.1732 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2271
# Epoch 92/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0675 - mae: 0.2125 - mse: 0.0675 - root_mean_squared_error: 0.2395 - val_loss: 0.0553 - val_mae: 0.1748 - val_mse: 0.0553 - val_root_mean_squared_error: 0.2352
# Epoch 93/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0732 - mae: 0.2168 - mse: 0.0732 - root_mean_squared_error: 0.3179 - val_loss: 0.0576 - val_mae: 0.1784 - val_mse: 0.0576 - val_root_mean_squared_error: 0.2399
# Epoch 94/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0742 - mae: 0.2180 - mse: 0.0742 - root_mean_squared_error: 0.2595 - val_loss: 0.0516 - val_mae: 0.1728 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2271
# Epoch 95/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0681 - mae: 0.2147 - mse: 0.0681 - root_mean_squared_error: 0.2919 - val_loss: 0.0604 - val_mae: 0.1945 - val_mse: 0.0604 - val_root_mean_squared_error: 0.2457
# Epoch 96/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0746 - mae: 0.2265 - mse: 0.0746 - root_mean_squared_error: 0.1902 - val_loss: 0.0738 - val_mae: 0.2255 - val_mse: 0.0738 - val_root_mean_squared_error: 0.2717
# Epoch 97/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0885 - mae: 0.2519 - mse: 0.0885 - root_mean_squared_error: 0.3147 - val_loss: 0.0669 - val_mae: 0.2109 - val_mse: 0.0669 - val_root_mean_squared_error: 0.2586
# Epoch 98/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0819 - mae: 0.2398 - mse: 0.0819 - root_mean_squared_error: 0.2705 - val_loss: 0.0529 - val_mae: 0.1774 - val_mse: 0.0529 - val_root_mean_squared_error: 0.2301
# Epoch 99/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0691 - mae: 0.2152 - mse: 0.0691 - root_mean_squared_error: 0.3149 - val_loss: 0.0535 - val_mae: 0.1729 - val_mse: 0.0535 - val_root_mean_squared_error: 0.2313
# Epoch 100/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0709 - mae: 0.2150 - mse: 0.0709 - root_mean_squared_error: 0.2244 - val_loss: 0.0631 - val_mae: 0.1912 - val_mse: 0.0631 - val_root_mean_squared_error: 0.2512
# Epoch 101/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0813 - mae: 0.2236 - mse: 0.0813 - root_mean_squared_error: 0.2317 - val_loss: 0.0697 - val_mae: 0.2063 - val_mse: 0.0697 - val_root_mean_squared_error: 0.2641
# Epoch 102/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0836 - mae: 0.2251 - mse: 0.0836 - root_mean_squared_error: 0.2681 - val_loss: 0.0594 - val_mae: 0.1820 - val_mse: 0.0594 - val_root_mean_squared_error: 0.2437
# Epoch 103/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0754 - mae: 0.2201 - mse: 0.0754 - root_mean_squared_error: 0.2695 - val_loss: 0.0516 - val_mae: 0.1744 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2272
# Epoch 104/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0690 - mae: 0.2170 - mse: 0.0690 - root_mean_squared_error: 0.2127 - val_loss: 0.0579 - val_mae: 0.1877 - val_mse: 0.0579 - val_root_mean_squared_error: 0.2406
# Epoch 105/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0736 - mae: 0.2250 - mse: 0.0736 - root_mean_squared_error: 0.2890 - val_loss: 0.0539 - val_mae: 0.1787 - val_mse: 0.0539 - val_root_mean_squared_error: 0.2321
# Epoch 106/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0701 - mae: 0.2202 - mse: 0.0701 - root_mean_squared_error: 0.2605 - val_loss: 0.0524 - val_mae: 0.1714 - val_mse: 0.0524 - val_root_mean_squared_error: 0.2290
# Epoch 107/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0697 - mae: 0.2143 - mse: 0.0697 - root_mean_squared_error: 0.3118 - val_loss: 0.0550 - val_mae: 0.1745 - val_mse: 0.0550 - val_root_mean_squared_error: 0.2344
# Epoch 108/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0725 - mae: 0.2171 - mse: 0.0725 - root_mean_squared_error: 0.3051 - val_loss: 0.0516 - val_mae: 0.1719 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2271
# Epoch 109/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0680 - mae: 0.2126 - mse: 0.0680 - root_mean_squared_error: 0.2123 - val_loss: 0.0569 - val_mae: 0.1854 - val_mse: 0.0569 - val_root_mean_squared_error: 0.2386
# Epoch 110/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0732 - mae: 0.2247 - mse: 0.0732 - root_mean_squared_error: 0.2274 - val_loss: 0.0644 - val_mae: 0.2052 - val_mse: 0.0644 - val_root_mean_squared_error: 0.2538
# Epoch 111/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0793 - mae: 0.2365 - mse: 0.0793 - root_mean_squared_error: 0.2734 - val_loss: 0.0584 - val_mae: 0.1890 - val_mse: 0.0584 - val_root_mean_squared_error: 0.2417
# Epoch 112/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0720 - mae: 0.2211 - mse: 0.0720 - root_mean_squared_error: 0.2420 - val_loss: 0.0515 - val_mae: 0.1736 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2268
# Epoch 113/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0692 - mae: 0.2143 - mse: 0.0692 - root_mean_squared_error: 0.2885 - val_loss: 0.0564 - val_mae: 0.1759 - val_mse: 0.0564 - val_root_mean_squared_error: 0.2374
# Epoch 114/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0739 - mae: 0.2179 - mse: 0.0739 - root_mean_squared_error: 0.2635 - val_loss: 0.0583 - val_mae: 0.1793 - val_mse: 0.0583 - val_root_mean_squared_error: 0.2414
# Epoch 115/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0751 - mae: 0.2194 - mse: 0.0751 - root_mean_squared_error: 0.2829 - val_loss: 0.0543 - val_mae: 0.1738 - val_mse: 0.0543 - val_root_mean_squared_error: 0.2330
# Epoch 116/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0697 - mae: 0.2143 - mse: 0.0697 - root_mean_squared_error: 0.3021 - val_loss: 0.0518 - val_mae: 0.1751 - val_mse: 0.0518 - val_root_mean_squared_error: 0.2275
# Epoch 117/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0697 - mae: 0.2180 - mse: 0.0697 - root_mean_squared_error: 0.2711 - val_loss: 0.0587 - val_mae: 0.1897 - val_mse: 0.0587 - val_root_mean_squared_error: 0.2422
# Epoch 118/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0752 - mae: 0.2287 - mse: 0.0752 - root_mean_squared_error: 0.2814 - val_loss: 0.0555 - val_mae: 0.1819 - val_mse: 0.0555 - val_root_mean_squared_error: 0.2355
# Epoch 119/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0699 - mae: 0.2183 - mse: 0.0699 - root_mean_squared_error: 0.2705 - val_loss: 0.0531 - val_mae: 0.1725 - val_mse: 0.0531 - val_root_mean_squared_error: 0.2305
# Epoch 120/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0686 - mae: 0.2112 - mse: 0.0686 - root_mean_squared_error: 0.2080 - val_loss: 0.0728 - val_mae: 0.2125 - val_mse: 0.0728 - val_root_mean_squared_error: 0.2698
# Epoch 121/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0905 - mae: 0.2307 - mse: 0.0905 - root_mean_squared_error: 0.2606 - val_loss: 0.0832 - val_mae: 0.2304 - val_mse: 0.0832 - val_root_mean_squared_error: 0.2885
# Epoch 122/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0991 - mae: 0.2386 - mse: 0.0991 - root_mean_squared_error: 0.3958 - val_loss: 0.0601 - val_mae: 0.1834 - val_mse: 0.0601 - val_root_mean_squared_error: 0.2451
# Epoch 123/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0740 - mae: 0.2156 - mse: 0.0740 - root_mean_squared_error: 0.2491 - val_loss: 0.0562 - val_mae: 0.1839 - val_mse: 0.0562 - val_root_mean_squared_error: 0.2371
# Epoch 124/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0753 - mae: 0.2268 - mse: 0.0753 - root_mean_squared_error: 0.3212 - val_loss: 0.0782 - val_mae: 0.2349 - val_mse: 0.0782 - val_root_mean_squared_error: 0.2797
# Epoch 125/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0928 - mae: 0.2581 - mse: 0.0928 - root_mean_squared_error: 0.3673 - val_loss: 0.0683 - val_mae: 0.2142 - val_mse: 0.0683 - val_root_mean_squared_error: 0.2613
# Epoch 126/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0837 - mae: 0.2413 - mse: 0.0837 - root_mean_squared_error: 0.2421 - val_loss: 0.0516 - val_mae: 0.1746 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2271
# Epoch 127/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0701 - mae: 0.2169 - mse: 0.0701 - root_mean_squared_error: 0.2733 - val_loss: 0.0580 - val_mae: 0.1789 - val_mse: 0.0580 - val_root_mean_squared_error: 0.2409
# Epoch 128/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0749 - mae: 0.2196 - mse: 0.0749 - root_mean_squared_error: 0.2813 - val_loss: 0.0600 - val_mae: 0.1830 - val_mse: 0.0600 - val_root_mean_squared_error: 0.2450
# Epoch 129/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0773 - mae: 0.2171 - mse: 0.0773 - root_mean_squared_error: 0.2400 - val_loss: 0.0528 - val_mae: 0.1721 - val_mse: 0.0528 - val_root_mean_squared_error: 0.2299
# Epoch 130/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0711 - mae: 0.2156 - mse: 0.0711 - root_mean_squared_error: 0.2515 - val_loss: 0.0523 - val_mae: 0.1764 - val_mse: 0.0523 - val_root_mean_squared_error: 0.2287
# Epoch 131/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0699 - mae: 0.2175 - mse: 0.0699 - root_mean_squared_error: 0.3053 - val_loss: 0.0567 - val_mae: 0.1849 - val_mse: 0.0567 - val_root_mean_squared_error: 0.2380
# Epoch 132/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0736 - mae: 0.2253 - mse: 0.0736 - root_mean_squared_error: 0.2965 - val_loss: 0.0622 - val_mae: 0.1998 - val_mse: 0.0622 - val_root_mean_squared_error: 0.2495
# Epoch 133/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0789 - mae: 0.2352 - mse: 0.0789 - root_mean_squared_error: 0.2499 - val_loss: 0.0607 - val_mae: 0.1955 - val_mse: 0.0607 - val_root_mean_squared_error: 0.2463
# Epoch 134/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0774 - mae: 0.2311 - mse: 0.0774 - root_mean_squared_error: 0.2986 - val_loss: 0.0538 - val_mae: 0.1786 - val_mse: 0.0538 - val_root_mean_squared_error: 0.2320
# Epoch 135/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0693 - mae: 0.2170 - mse: 0.0693 - root_mean_squared_error: 0.2678 - val_loss: 0.0521 - val_mae: 0.1709 - val_mse: 0.0521 - val_root_mean_squared_error: 0.2282
# Epoch 136/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0681 - mae: 0.2138 - mse: 0.0681 - root_mean_squared_error: 0.2003 - val_loss: 0.0626 - val_mae: 0.1902 - val_mse: 0.0626 - val_root_mean_squared_error: 0.2503
# Epoch 137/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0781 - mae: 0.2212 - mse: 0.0781 - root_mean_squared_error: 0.2886 - val_loss: 0.0680 - val_mae: 0.2029 - val_mse: 0.0680 - val_root_mean_squared_error: 0.2608
# Epoch 138/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0816 - mae: 0.2238 - mse: 0.0816 - root_mean_squared_error: 0.2410 - val_loss: 0.0615 - val_mae: 0.1870 - val_mse: 0.0615 - val_root_mean_squared_error: 0.2479
# Epoch 139/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0764 - mae: 0.2176 - mse: 0.0764 - root_mean_squared_error: 0.2157 - val_loss: 0.0539 - val_mae: 0.1734 - val_mse: 0.0539 - val_root_mean_squared_error: 0.2321
# Epoch 140/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0706 - mae: 0.2165 - mse: 0.0706 - root_mean_squared_error: 0.2090 - val_loss: 0.0514 - val_mae: 0.1733 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 141/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0698 - mae: 0.2170 - mse: 0.0698 - root_mean_squared_error: 0.2613 - val_loss: 0.0515 - val_mae: 0.1740 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2269
# Epoch 142/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0683 - mae: 0.2144 - mse: 0.0683 - root_mean_squared_error: 0.2886 - val_loss: 0.0515 - val_mae: 0.1721 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2270
# Epoch 143/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0677 - mae: 0.2135 - mse: 0.0677 - root_mean_squared_error: 0.1949 - val_loss: 0.0515 - val_mae: 0.1724 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2269
# Epoch 144/200
# 2/2 [==============================] - 0s 91ms/step - loss: 0.0680 - mae: 0.2136 - mse: 0.0680 - root_mean_squared_error: 0.2408 - val_loss: 0.0514 - val_mae: 0.1730 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 145/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0678 - mae: 0.2135 - mse: 0.0678 - root_mean_squared_error: 0.2190 - val_loss: 0.0515 - val_mae: 0.1727 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2268
# Epoch 146/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0675 - mae: 0.2128 - mse: 0.0675 - root_mean_squared_error: 0.2557 - val_loss: 0.0515 - val_mae: 0.1728 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2268
# Epoch 147/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0680 - mae: 0.2136 - mse: 0.0680 - root_mean_squared_error: 0.3256 - val_loss: 0.0516 - val_mae: 0.1746 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2272
# Epoch 148/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0688 - mae: 0.2150 - mse: 0.0688 - root_mean_squared_error: 0.2482 - val_loss: 0.0516 - val_mae: 0.1747 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2272
# Epoch 149/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0674 - mae: 0.2131 - mse: 0.0674 - root_mean_squared_error: 0.2171 - val_loss: 0.0519 - val_mae: 0.1710 - val_mse: 0.0519 - val_root_mean_squared_error: 0.2278
# Epoch 150/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0673 - mae: 0.2117 - mse: 0.0673 - root_mean_squared_error: 0.2372 - val_loss: 0.0549 - val_mae: 0.1744 - val_mse: 0.0549 - val_root_mean_squared_error: 0.2343
# Epoch 151/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0700 - mae: 0.2147 - mse: 0.0700 - root_mean_squared_error: 0.3278 - val_loss: 0.0555 - val_mae: 0.1749 - val_mse: 0.0555 - val_root_mean_squared_error: 0.2355
# Epoch 152/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0707 - mae: 0.2155 - mse: 0.0707 - root_mean_squared_error: 0.2743 - val_loss: 0.0517 - val_mae: 0.1715 - val_mse: 0.0517 - val_root_mean_squared_error: 0.2273
# Epoch 153/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0670 - mae: 0.2121 - mse: 0.0670 - root_mean_squared_error: 0.3022 - val_loss: 0.0561 - val_mae: 0.1836 - val_mse: 0.0561 - val_root_mean_squared_error: 0.2369
# Epoch 154/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0734 - mae: 0.2247 - mse: 0.0734 - root_mean_squared_error: 0.2249 - val_loss: 0.0685 - val_mae: 0.2146 - val_mse: 0.0685 - val_root_mean_squared_error: 0.2617
# Epoch 155/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0840 - mae: 0.2452 - mse: 0.0840 - root_mean_squared_error: 0.2479 - val_loss: 0.0682 - val_mae: 0.2140 - val_mse: 0.0682 - val_root_mean_squared_error: 0.2612
# Epoch 156/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0828 - mae: 0.2432 - mse: 0.0828 - root_mean_squared_error: 0.3148 - val_loss: 0.0541 - val_mae: 0.1789 - val_mse: 0.0541 - val_root_mean_squared_error: 0.2325
# Epoch 157/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0691 - mae: 0.2160 - mse: 0.0691 - root_mean_squared_error: 0.2138 - val_loss: 0.0564 - val_mae: 0.1759 - val_mse: 0.0564 - val_root_mean_squared_error: 0.2374
# Epoch 158/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0727 - mae: 0.2169 - mse: 0.0727 - root_mean_squared_error: 0.2897 - val_loss: 0.0737 - val_mae: 0.2143 - val_mse: 0.0737 - val_root_mean_squared_error: 0.2716
# Epoch 159/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0865 - mae: 0.2300 - mse: 0.0865 - root_mean_squared_error: 0.2314 - val_loss: 0.0762 - val_mae: 0.2187 - val_mse: 0.0762 - val_root_mean_squared_error: 0.2760
# Epoch 160/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0875 - mae: 0.2277 - mse: 0.0875 - root_mean_squared_error: 0.2250 - val_loss: 0.0631 - val_mae: 0.1913 - val_mse: 0.0631 - val_root_mean_squared_error: 0.2512
# Epoch 161/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0756 - mae: 0.2186 - mse: 0.0756 - root_mean_squared_error: 0.2817 - val_loss: 0.0517 - val_mae: 0.1713 - val_mse: 0.0517 - val_root_mean_squared_error: 0.2274
# Epoch 162/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0671 - mae: 0.2127 - mse: 0.0671 - root_mean_squared_error: 0.2928 - val_loss: 0.0600 - val_mae: 0.1934 - val_mse: 0.0600 - val_root_mean_squared_error: 0.2449
# Epoch 163/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0788 - mae: 0.2356 - mse: 0.0788 - root_mean_squared_error: 0.2677 - val_loss: 0.0731 - val_mae: 0.2238 - val_mse: 0.0731 - val_root_mean_squared_error: 0.2703
# Epoch 164/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0913 - mae: 0.2563 - mse: 0.0913 - root_mean_squared_error: 0.3506 - val_loss: 0.0591 - val_mae: 0.1908 - val_mse: 0.0591 - val_root_mean_squared_error: 0.2430
# Epoch 165/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0741 - mae: 0.2256 - mse: 0.0741 - root_mean_squared_error: 0.2888 - val_loss: 0.0524 - val_mae: 0.1714 - val_mse: 0.0524 - val_root_mean_squared_error: 0.2290
# Epoch 166/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0690 - mae: 0.2150 - mse: 0.0690 - root_mean_squared_error: 0.2575 - val_loss: 0.0648 - val_mae: 0.1955 - val_mse: 0.0648 - val_root_mean_squared_error: 0.2545
# Epoch 167/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0800 - mae: 0.2234 - mse: 0.0800 - root_mean_squared_error: 0.2874 - val_loss: 0.0664 - val_mae: 0.1994 - val_mse: 0.0664 - val_root_mean_squared_error: 0.2577
# Epoch 168/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0796 - mae: 0.2223 - mse: 0.0796 - root_mean_squared_error: 0.3060 - val_loss: 0.0545 - val_mae: 0.1740 - val_mse: 0.0545 - val_root_mean_squared_error: 0.2334
# Epoch 169/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0693 - mae: 0.2130 - mse: 0.0693 - root_mean_squared_error: 0.2361 - val_loss: 0.0531 - val_mae: 0.1776 - val_mse: 0.0531 - val_root_mean_squared_error: 0.2303
# Epoch 170/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0701 - mae: 0.2178 - mse: 0.0701 - root_mean_squared_error: 0.2308 - val_loss: 0.0629 - val_mae: 0.2016 - val_mse: 0.0629 - val_root_mean_squared_error: 0.2508
# Epoch 171/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0809 - mae: 0.2394 - mse: 0.0809 - root_mean_squared_error: 0.2712 - val_loss: 0.0645 - val_mae: 0.2056 - val_mse: 0.0645 - val_root_mean_squared_error: 0.2540
# Epoch 172/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0819 - mae: 0.2406 - mse: 0.0819 - root_mean_squared_error: 0.2745 - val_loss: 0.0548 - val_mae: 0.1804 - val_mse: 0.0548 - val_root_mean_squared_error: 0.2342
# Epoch 173/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0718 - mae: 0.2214 - mse: 0.0718 - root_mean_squared_error: 0.3143 - val_loss: 0.0518 - val_mae: 0.1710 - val_mse: 0.0518 - val_root_mean_squared_error: 0.2277
# Epoch 174/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0679 - mae: 0.2143 - mse: 0.0679 - root_mean_squared_error: 0.2347 - val_loss: 0.0567 - val_mae: 0.1763 - val_mse: 0.0567 - val_root_mean_squared_error: 0.2381
# Epoch 175/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0726 - mae: 0.2166 - mse: 0.0726 - root_mean_squared_error: 0.2844 - val_loss: 0.0580 - val_mae: 0.1788 - val_mse: 0.0580 - val_root_mean_squared_error: 0.2408
# Epoch 176/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0726 - mae: 0.2170 - mse: 0.0726 - root_mean_squared_error: 0.2853 - val_loss: 0.0535 - val_mae: 0.1729 - val_mse: 0.0535 - val_root_mean_squared_error: 0.2313
# Epoch 177/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0690 - mae: 0.2142 - mse: 0.0690 - root_mean_squared_error: 0.2472 - val_loss: 0.0514 - val_mae: 0.1735 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 178/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0676 - mae: 0.2134 - mse: 0.0676 - root_mean_squared_error: 0.3097 - val_loss: 0.0550 - val_mae: 0.1807 - val_mse: 0.0550 - val_root_mean_squared_error: 0.2345
# Epoch 179/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0724 - mae: 0.2219 - mse: 0.0724 - root_mean_squared_error: 0.2508 - val_loss: 0.0636 - val_mae: 0.2034 - val_mse: 0.0636 - val_root_mean_squared_error: 0.2522
# Epoch 180/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0795 - mae: 0.2365 - mse: 0.0795 - root_mean_squared_error: 0.1982 - val_loss: 0.0644 - val_mae: 0.2054 - val_mse: 0.0644 - val_root_mean_squared_error: 0.2539
# Epoch 181/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0806 - mae: 0.2376 - mse: 0.0806 - root_mean_squared_error: 0.2987 - val_loss: 0.0598 - val_mae: 0.1929 - val_mse: 0.0598 - val_root_mean_squared_error: 0.2446
# Epoch 182/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0759 - mae: 0.2298 - mse: 0.0759 - root_mean_squared_error: 0.3086 - val_loss: 0.0541 - val_mae: 0.1790 - val_mse: 0.0541 - val_root_mean_squared_error: 0.2326
# Epoch 183/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0707 - mae: 0.2188 - mse: 0.0707 - root_mean_squared_error: 0.2699 - val_loss: 0.0514 - val_mae: 0.1735 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 184/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0676 - mae: 0.2129 - mse: 0.0676 - root_mean_squared_error: 0.2723 - val_loss: 0.0526 - val_mae: 0.1716 - val_mse: 0.0526 - val_root_mean_squared_error: 0.2293
# Epoch 185/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0681 - mae: 0.2133 - mse: 0.0681 - root_mean_squared_error: 0.2478 - val_loss: 0.0545 - val_mae: 0.1740 - val_mse: 0.0545 - val_root_mean_squared_error: 0.2335
# Epoch 186/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0699 - mae: 0.2148 - mse: 0.0699 - root_mean_squared_error: 0.2641 - val_loss: 0.0557 - val_mae: 0.1751 - val_mse: 0.0557 - val_root_mean_squared_error: 0.2360
# Epoch 187/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0707 - mae: 0.2154 - mse: 0.0707 - root_mean_squared_error: 0.2453 - val_loss: 0.0535 - val_mae: 0.1730 - val_mse: 0.0535 - val_root_mean_squared_error: 0.2314
# Epoch 188/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0693 - mae: 0.2140 - mse: 0.0693 - root_mean_squared_error: 0.1945 - val_loss: 0.0515 - val_mae: 0.1724 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2269
# Epoch 189/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0677 - mae: 0.2134 - mse: 0.0677 - root_mean_squared_error: 0.2091 - val_loss: 0.0517 - val_mae: 0.1750 - val_mse: 0.0517 - val_root_mean_squared_error: 0.2274
# Epoch 190/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0677 - mae: 0.2137 - mse: 0.0677 - root_mean_squared_error: 0.2353 - val_loss: 0.0524 - val_mae: 0.1766 - val_mse: 0.0524 - val_root_mean_squared_error: 0.2289
# Epoch 191/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0688 - mae: 0.2160 - mse: 0.0688 - root_mean_squared_error: 0.3023 - val_loss: 0.0535 - val_mae: 0.1782 - val_mse: 0.0535 - val_root_mean_squared_error: 0.2313
# Epoch 192/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0702 - mae: 0.2186 - mse: 0.0702 - root_mean_squared_error: 0.2574 - val_loss: 0.0536 - val_mae: 0.1783 - val_mse: 0.0536 - val_root_mean_squared_error: 0.2315
# Epoch 193/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0702 - mae: 0.2188 - mse: 0.0702 - root_mean_squared_error: 0.2855 - val_loss: 0.0518 - val_mae: 0.1754 - val_mse: 0.0518 - val_root_mean_squared_error: 0.2277
# Epoch 194/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0699 - mae: 0.2174 - mse: 0.0699 - root_mean_squared_error: 0.3149 - val_loss: 0.0514 - val_mae: 0.1730 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 195/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0676 - mae: 0.2135 - mse: 0.0676 - root_mean_squared_error: 0.2234 - val_loss: 0.0515 - val_mae: 0.1741 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2269
# Epoch 196/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0677 - mae: 0.2135 - mse: 0.0677 - root_mean_squared_error: 0.2319 - val_loss: 0.0515 - val_mae: 0.1739 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2269
# Epoch 197/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0679 - mae: 0.2138 - mse: 0.0679 - root_mean_squared_error: 0.2308 - val_loss: 0.0516 - val_mae: 0.1716 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2272
# Epoch 198/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0675 - mae: 0.2127 - mse: 0.0675 - root_mean_squared_error: 0.2362 - val_loss: 0.0528 - val_mae: 0.1719 - val_mse: 0.0528 - val_root_mean_squared_error: 0.2297
# Epoch 199/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0683 - mae: 0.2136 - mse: 0.0683 - root_mean_squared_error: 0.2561 - val_loss: 0.0541 - val_mae: 0.1737 - val_mse: 0.0541 - val_root_mean_squared_error: 0.2327
# Epoch 200/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0696 - mae: 0.2156 - mse: 0.0696 - root_mean_squared_error: 0.2201 - val_loss: 0.0550 - val_mae: 0.1745 - val_mse: 0.0550 - val_root_mean_squared_error: 0.2346

# %%
# Train the keras model
keras_model.fit(train_data_inputs, train_data_targets,
          validation_data=(val_data_inputs, val_data_targets),
          epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/200
# 2/2 [==============================] - 10s 1s/step - loss: 1.1596 - mae: 1.0084 - mse: 1.1596 - root_mean_squared_error: 0.7943 - val_loss: 0.1874 - val_mae: 0.3944 - val_mse: 0.1874 - val_root_mean_squared_error: 0.4329
# Epoch 2/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.4549 - mae: 0.5694 - mse: 0.4549 - root_mean_squared_error: 0.6633 - val_loss: 0.1573 - val_mae: 0.3607 - val_mse: 0.1573 - val_root_mean_squared_error: 0.3966
# Epoch 3/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.4056 - mae: 0.5319 - mse: 0.4056 - root_mean_squared_error: 0.5857 - val_loss: 0.1269 - val_mae: 0.3212 - val_mse: 0.1269 - val_root_mean_squared_error: 0.3562
# Epoch 4/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.3062 - mae: 0.4546 - mse: 0.3062 - root_mean_squared_error: 0.5669 - val_loss: 0.1006 - val_mae: 0.2800 - val_mse: 0.1006 - val_root_mean_squared_error: 0.3171
# Epoch 5/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.2220 - mae: 0.3802 - mse: 0.2220 - root_mean_squared_error: 0.4469 - val_loss: 0.0802 - val_mae: 0.2395 - val_mse: 0.0802 - val_root_mean_squared_error: 0.2831
# Epoch 6/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2544 - mae: 0.4002 - mse: 0.2544 - root_mean_squared_error: 0.6269 - val_loss: 0.7386 - val_mae: 0.8290 - val_mse: 0.7386 - val_root_mean_squared_error: 0.8594
# Epoch 7/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5676 - mae: 0.6741 - mse: 0.5676 - root_mean_squared_error: 0.8270 - val_loss: 0.6243 - val_mae: 0.7569 - val_mse: 0.6243 - val_root_mean_squared_error: 0.7901
# Epoch 8/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5593 - mae: 0.6891 - mse: 0.5593 - root_mean_squared_error: 0.6948 - val_loss: 0.5049 - val_mae: 0.6734 - val_mse: 0.5049 - val_root_mean_squared_error: 0.7106
# Epoch 9/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.3625 - mae: 0.5183 - mse: 0.3625 - root_mean_squared_error: 0.5163 - val_loss: 0.3969 - val_mae: 0.5878 - val_mse: 0.3969 - val_root_mean_squared_error: 0.6300
# Epoch 10/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.3041 - mae: 0.4728 - mse: 0.3041 - root_mean_squared_error: 0.4562 - val_loss: 0.3042 - val_mae: 0.5028 - val_mse: 0.3042 - val_root_mean_squared_error: 0.5515
# Epoch 11/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.2375 - mae: 0.4119 - mse: 0.2375 - root_mean_squared_error: 0.4533 - val_loss: 0.2268 - val_mae: 0.4188 - val_mse: 0.2268 - val_root_mean_squared_error: 0.4763
# Epoch 12/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1891 - mae: 0.3537 - mse: 0.1891 - root_mean_squared_error: 0.3256 - val_loss: 0.1652 - val_mae: 0.3393 - val_mse: 0.1652 - val_root_mean_squared_error: 0.4065
# Epoch 13/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1426 - mae: 0.2958 - mse: 0.1426 - root_mean_squared_error: 0.3891 - val_loss: 0.1187 - val_mae: 0.2786 - val_mse: 0.1187 - val_root_mean_squared_error: 0.3445
# Epoch 14/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1169 - mae: 0.2574 - mse: 0.1169 - root_mean_squared_error: 0.2392 - val_loss: 0.0861 - val_mae: 0.2347 - val_mse: 0.0861 - val_root_mean_squared_error: 0.2934
# Epoch 15/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0908 - mae: 0.2284 - mse: 0.0908 - root_mean_squared_error: 0.2388 - val_loss: 0.0661 - val_mae: 0.1986 - val_mse: 0.0661 - val_root_mean_squared_error: 0.2571
# Epoch 16/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0770 - mae: 0.2219 - mse: 0.0770 - root_mean_squared_error: 0.2800 - val_loss: 0.0555 - val_mae: 0.1750 - val_mse: 0.0555 - val_root_mean_squared_error: 0.2355
# Epoch 17/200
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0693 - mae: 0.2138 - mse: 0.0693 - root_mean_squared_error: 0.3193 - val_loss: 0.0516 - val_mae: 0.1717 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2271
# Epoch 18/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0690 - mae: 0.2145 - mse: 0.0690 - root_mean_squared_error: 0.2394 - val_loss: 0.0523 - val_mae: 0.1764 - val_mse: 0.0523 - val_root_mean_squared_error: 0.2287
# Epoch 19/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0722 - mae: 0.2178 - mse: 0.0722 - root_mean_squared_error: 0.2208 - val_loss: 0.0551 - val_mae: 0.1811 - val_mse: 0.0551 - val_root_mean_squared_error: 0.2348
# Epoch 20/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0740 - mae: 0.2229 - mse: 0.0740 - root_mean_squared_error: 0.2754 - val_loss: 0.0586 - val_mae: 0.1891 - val_mse: 0.0586 - val_root_mean_squared_error: 0.2420
# Epoch 21/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0771 - mae: 0.2287 - mse: 0.0771 - root_mean_squared_error: 0.2209 - val_loss: 0.0618 - val_mae: 0.1988 - val_mse: 0.0618 - val_root_mean_squared_error: 0.2487
# Epoch 22/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0821 - mae: 0.2420 - mse: 0.0821 - root_mean_squared_error: 0.2284 - val_loss: 0.0639 - val_mae: 0.2041 - val_mse: 0.0639 - val_root_mean_squared_error: 0.2528
# Epoch 23/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0803 - mae: 0.2382 - mse: 0.0803 - root_mean_squared_error: 0.2887 - val_loss: 0.0648 - val_mae: 0.2063 - val_mse: 0.0648 - val_root_mean_squared_error: 0.2546
# Epoch 24/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0849 - mae: 0.2447 - mse: 0.0849 - root_mean_squared_error: 0.3181 - val_loss: 0.0636 - val_mae: 0.2034 - val_mse: 0.0636 - val_root_mean_squared_error: 0.2522
# Epoch 25/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0812 - mae: 0.2390 - mse: 0.0812 - root_mean_squared_error: 0.3187 - val_loss: 0.0609 - val_mae: 0.1961 - val_mse: 0.0609 - val_root_mean_squared_error: 0.2468
# Epoch 26/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0769 - mae: 0.2292 - mse: 0.0769 - root_mean_squared_error: 0.2385 - val_loss: 0.0582 - val_mae: 0.1883 - val_mse: 0.0582 - val_root_mean_squared_error: 0.2413
# Epoch 27/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0747 - mae: 0.2259 - mse: 0.0747 - root_mean_squared_error: 0.2825 - val_loss: 0.0559 - val_mae: 0.1830 - val_mse: 0.0559 - val_root_mean_squared_error: 0.2364
# Epoch 28/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0720 - mae: 0.2214 - mse: 0.0720 - root_mean_squared_error: 0.2749 - val_loss: 0.0544 - val_mae: 0.1792 - val_mse: 0.0544 - val_root_mean_squared_error: 0.2332
# Epoch 29/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0718 - mae: 0.2212 - mse: 0.0718 - root_mean_squared_error: 0.2997 - val_loss: 0.0535 - val_mae: 0.1783 - val_mse: 0.0535 - val_root_mean_squared_error: 0.2314
# Epoch 30/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0711 - mae: 0.2186 - mse: 0.0711 - root_mean_squared_error: 0.2270 - val_loss: 0.0529 - val_mae: 0.1775 - val_mse: 0.0529 - val_root_mean_squared_error: 0.2300
# Epoch 31/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0696 - mae: 0.2165 - mse: 0.0696 - root_mean_squared_error: 0.2243 - val_loss: 0.0522 - val_mae: 0.1762 - val_mse: 0.0522 - val_root_mean_squared_error: 0.2284
# Epoch 32/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0696 - mae: 0.2169 - mse: 0.0696 - root_mean_squared_error: 0.3011 - val_loss: 0.0516 - val_mae: 0.1748 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2272
# Epoch 33/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0690 - mae: 0.2154 - mse: 0.0690 - root_mean_squared_error: 0.2774 - val_loss: 0.0514 - val_mae: 0.1733 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 34/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0674 - mae: 0.2129 - mse: 0.0674 - root_mean_squared_error: 0.2292 - val_loss: 0.0517 - val_mae: 0.1714 - val_mse: 0.0517 - val_root_mean_squared_error: 0.2273
# Epoch 35/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0674 - mae: 0.2127 - mse: 0.0674 - root_mean_squared_error: 0.3251 - val_loss: 0.0522 - val_mae: 0.1710 - val_mse: 0.0522 - val_root_mean_squared_error: 0.2285
# Epoch 36/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0672 - mae: 0.2124 - mse: 0.0672 - root_mean_squared_error: 0.2980 - val_loss: 0.0526 - val_mae: 0.1718 - val_mse: 0.0526 - val_root_mean_squared_error: 0.2294
# Epoch 37/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0673 - mae: 0.2127 - mse: 0.0673 - root_mean_squared_error: 0.2933 - val_loss: 0.0528 - val_mae: 0.1720 - val_mse: 0.0528 - val_root_mean_squared_error: 0.2297
# Epoch 38/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0672 - mae: 0.2126 - mse: 0.0672 - root_mean_squared_error: 0.2145 - val_loss: 0.0527 - val_mae: 0.1718 - val_mse: 0.0527 - val_root_mean_squared_error: 0.2295
# Epoch 39/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0672 - mae: 0.2125 - mse: 0.0672 - root_mean_squared_error: 0.1883 - val_loss: 0.0526 - val_mae: 0.1717 - val_mse: 0.0526 - val_root_mean_squared_error: 0.2293
# Epoch 40/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0671 - mae: 0.2124 - mse: 0.0671 - root_mean_squared_error: 0.2292 - val_loss: 0.0525 - val_mae: 0.1716 - val_mse: 0.0525 - val_root_mean_squared_error: 0.2292
# Epoch 41/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0671 - mae: 0.2123 - mse: 0.0671 - root_mean_squared_error: 0.1958 - val_loss: 0.0525 - val_mae: 0.1716 - val_mse: 0.0525 - val_root_mean_squared_error: 0.2291
# Epoch 42/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0671 - mae: 0.2123 - mse: 0.0671 - root_mean_squared_error: 0.2255 - val_loss: 0.0525 - val_mae: 0.1715 - val_mse: 0.0525 - val_root_mean_squared_error: 0.2290
# Epoch 43/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0671 - mae: 0.2123 - mse: 0.0671 - root_mean_squared_error: 0.2406 - val_loss: 0.0525 - val_mae: 0.1715 - val_mse: 0.0525 - val_root_mean_squared_error: 0.2290
# Epoch 44/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0670 - mae: 0.2123 - mse: 0.0670 - root_mean_squared_error: 0.2122 - val_loss: 0.0525 - val_mae: 0.1716 - val_mse: 0.0525 - val_root_mean_squared_error: 0.2292
# Epoch 45/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0671 - mae: 0.2123 - mse: 0.0671 - root_mean_squared_error: 0.3023 - val_loss: 0.0524 - val_mae: 0.1714 - val_mse: 0.0524 - val_root_mean_squared_error: 0.2289
# Epoch 46/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0670 - mae: 0.2123 - mse: 0.0670 - root_mean_squared_error: 0.2580 - val_loss: 0.0522 - val_mae: 0.1709 - val_mse: 0.0522 - val_root_mean_squared_error: 0.2284
# Epoch 47/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0669 - mae: 0.2121 - mse: 0.0669 - root_mean_squared_error: 0.2780 - val_loss: 0.0520 - val_mae: 0.1706 - val_mse: 0.0520 - val_root_mean_squared_error: 0.2280
# Epoch 48/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0669 - mae: 0.2120 - mse: 0.0669 - root_mean_squared_error: 0.3097 - val_loss: 0.0518 - val_mae: 0.1711 - val_mse: 0.0518 - val_root_mean_squared_error: 0.2275
# Epoch 49/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0668 - mae: 0.2119 - mse: 0.0668 - root_mean_squared_error: 0.2851 - val_loss: 0.0515 - val_mae: 0.1719 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2270
# Epoch 50/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0670 - mae: 0.2126 - mse: 0.0670 - root_mean_squared_error: 0.2403 - val_loss: 0.0514 - val_mae: 0.1726 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 51/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0670 - mae: 0.2125 - mse: 0.0670 - root_mean_squared_error: 0.2592 - val_loss: 0.0514 - val_mae: 0.1729 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 52/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0669 - mae: 0.2125 - mse: 0.0669 - root_mean_squared_error: 0.3035 - val_loss: 0.0514 - val_mae: 0.1735 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 53/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0671 - mae: 0.2127 - mse: 0.0671 - root_mean_squared_error: 0.2376 - val_loss: 0.0515 - val_mae: 0.1742 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2270
# Epoch 54/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0675 - mae: 0.2134 - mse: 0.0675 - root_mean_squared_error: 0.2450 - val_loss: 0.0515 - val_mae: 0.1743 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2270
# Epoch 55/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0674 - mae: 0.2131 - mse: 0.0674 - root_mean_squared_error: 0.2260 - val_loss: 0.0515 - val_mae: 0.1739 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2269
# Epoch 56/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0673 - mae: 0.2131 - mse: 0.0673 - root_mean_squared_error: 0.1943 - val_loss: 0.0514 - val_mae: 0.1733 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 57/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0671 - mae: 0.2127 - mse: 0.0671 - root_mean_squared_error: 0.2339 - val_loss: 0.0514 - val_mae: 0.1726 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 58/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0668 - mae: 0.2123 - mse: 0.0668 - root_mean_squared_error: 0.2230 - val_loss: 0.0516 - val_mae: 0.1717 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2272
# Epoch 59/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0669 - mae: 0.2121 - mse: 0.0669 - root_mean_squared_error: 0.2165 - val_loss: 0.0519 - val_mae: 0.1706 - val_mse: 0.0519 - val_root_mean_squared_error: 0.2279
# Epoch 60/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0669 - mae: 0.2120 - mse: 0.0669 - root_mean_squared_error: 0.2043 - val_loss: 0.0523 - val_mae: 0.1713 - val_mse: 0.0523 - val_root_mean_squared_error: 0.2288
# Epoch 61/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0670 - mae: 0.2122 - mse: 0.0670 - root_mean_squared_error: 0.2779 - val_loss: 0.0528 - val_mae: 0.1720 - val_mse: 0.0528 - val_root_mean_squared_error: 0.2297
# Epoch 62/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0673 - mae: 0.2127 - mse: 0.0673 - root_mean_squared_error: 0.2429 - val_loss: 0.0530 - val_mae: 0.1723 - val_mse: 0.0530 - val_root_mean_squared_error: 0.2302
# Epoch 63/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0673 - mae: 0.2128 - mse: 0.0673 - root_mean_squared_error: 0.2275 - val_loss: 0.0529 - val_mae: 0.1722 - val_mse: 0.0529 - val_root_mean_squared_error: 0.2301
# Epoch 64/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0672 - mae: 0.2126 - mse: 0.0672 - root_mean_squared_error: 0.2059 - val_loss: 0.0530 - val_mae: 0.1723 - val_mse: 0.0530 - val_root_mean_squared_error: 0.2302
# Epoch 65/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0674 - mae: 0.2128 - mse: 0.0674 - root_mean_squared_error: 0.2947 - val_loss: 0.0528 - val_mae: 0.1720 - val_mse: 0.0528 - val_root_mean_squared_error: 0.2298
# Epoch 66/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0671 - mae: 0.2125 - mse: 0.0671 - root_mean_squared_error: 0.3023 - val_loss: 0.0524 - val_mae: 0.1713 - val_mse: 0.0524 - val_root_mean_squared_error: 0.2288
# Epoch 67/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0670 - mae: 0.2124 - mse: 0.0670 - root_mean_squared_error: 0.3047 - val_loss: 0.0520 - val_mae: 0.1706 - val_mse: 0.0520 - val_root_mean_squared_error: 0.2279
# Epoch 68/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0669 - mae: 0.2120 - mse: 0.0669 - root_mean_squared_error: 0.3046 - val_loss: 0.0517 - val_mae: 0.1713 - val_mse: 0.0517 - val_root_mean_squared_error: 0.2274
# Epoch 69/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0669 - mae: 0.2120 - mse: 0.0669 - root_mean_squared_error: 0.2570 - val_loss: 0.0516 - val_mae: 0.1719 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2270
# Epoch 70/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0669 - mae: 0.2122 - mse: 0.0669 - root_mean_squared_error: 0.2071 - val_loss: 0.0515 - val_mae: 0.1723 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2269
# Epoch 71/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0671 - mae: 0.2124 - mse: 0.0671 - root_mean_squared_error: 0.3233 - val_loss: 0.0515 - val_mae: 0.1725 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2268
# Epoch 72/200
# 2/2 [==============================] - 0s 91ms/step - loss: 0.0669 - mae: 0.2124 - mse: 0.0669 - root_mean_squared_error: 0.2859 - val_loss: 0.0514 - val_mae: 0.1728 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 73/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0670 - mae: 0.2126 - mse: 0.0670 - root_mean_squared_error: 0.2584 - val_loss: 0.0514 - val_mae: 0.1731 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 74/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0673 - mae: 0.2130 - mse: 0.0673 - root_mean_squared_error: 0.2390 - val_loss: 0.0514 - val_mae: 0.1732 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 75/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0672 - mae: 0.2129 - mse: 0.0672 - root_mean_squared_error: 0.3205 - val_loss: 0.0514 - val_mae: 0.1732 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 76/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0672 - mae: 0.2132 - mse: 0.0672 - root_mean_squared_error: 0.2307 - val_loss: 0.0514 - val_mae: 0.1734 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 77/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0672 - mae: 0.2130 - mse: 0.0672 - root_mean_squared_error: 0.2463 - val_loss: 0.0514 - val_mae: 0.1729 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 78/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0672 - mae: 0.2128 - mse: 0.0672 - root_mean_squared_error: 0.3035 - val_loss: 0.0515 - val_mae: 0.1722 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2269
# Epoch 79/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0669 - mae: 0.2125 - mse: 0.0669 - root_mean_squared_error: 0.2398 - val_loss: 0.0516 - val_mae: 0.1718 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2271
# Epoch 80/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0669 - mae: 0.2124 - mse: 0.0669 - root_mean_squared_error: 0.2494 - val_loss: 0.0518 - val_mae: 0.1711 - val_mse: 0.0518 - val_root_mean_squared_error: 0.2275
# Epoch 81/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0670 - mae: 0.2122 - mse: 0.0670 - root_mean_squared_error: 0.3060 - val_loss: 0.0520 - val_mae: 0.1705 - val_mse: 0.0520 - val_root_mean_squared_error: 0.2280
# Epoch 82/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0670 - mae: 0.2123 - mse: 0.0670 - root_mean_squared_error: 0.2452 - val_loss: 0.0521 - val_mae: 0.1709 - val_mse: 0.0521 - val_root_mean_squared_error: 0.2283
# Epoch 83/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0670 - mae: 0.2126 - mse: 0.0670 - root_mean_squared_error: 0.1990 - val_loss: 0.0522 - val_mae: 0.1710 - val_mse: 0.0522 - val_root_mean_squared_error: 0.2284
# Epoch 84/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0669 - mae: 0.2122 - mse: 0.0669 - root_mean_squared_error: 0.2118 - val_loss: 0.0521 - val_mae: 0.1708 - val_mse: 0.0521 - val_root_mean_squared_error: 0.2283
# Epoch 85/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0669 - mae: 0.2121 - mse: 0.0669 - root_mean_squared_error: 0.3012 - val_loss: 0.0518 - val_mae: 0.1710 - val_mse: 0.0518 - val_root_mean_squared_error: 0.2276
# Epoch 86/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0670 - mae: 0.2123 - mse: 0.0670 - root_mean_squared_error: 0.2180 - val_loss: 0.0515 - val_mae: 0.1720 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2270
# Epoch 87/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0670 - mae: 0.2125 - mse: 0.0670 - root_mean_squared_error: 0.2815 - val_loss: 0.0515 - val_mae: 0.1725 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2268
# Epoch 88/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0670 - mae: 0.2127 - mse: 0.0670 - root_mean_squared_error: 0.2838 - val_loss: 0.0514 - val_mae: 0.1728 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 89/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0670 - mae: 0.2128 - mse: 0.0670 - root_mean_squared_error: 0.2428 - val_loss: 0.0514 - val_mae: 0.1730 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 90/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0671 - mae: 0.2129 - mse: 0.0671 - root_mean_squared_error: 0.2989 - val_loss: 0.0514 - val_mae: 0.1731 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 91/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0671 - mae: 0.2129 - mse: 0.0671 - root_mean_squared_error: 0.2766 - val_loss: 0.0514 - val_mae: 0.1731 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 92/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0671 - mae: 0.2129 - mse: 0.0671 - root_mean_squared_error: 0.1721 - val_loss: 0.0514 - val_mae: 0.1730 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 93/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0671 - mae: 0.2129 - mse: 0.0671 - root_mean_squared_error: 0.2024 - val_loss: 0.0514 - val_mae: 0.1728 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 94/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0670 - mae: 0.2127 - mse: 0.0670 - root_mean_squared_error: 0.2369 - val_loss: 0.0515 - val_mae: 0.1721 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2270
# Epoch 95/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0668 - mae: 0.2123 - mse: 0.0668 - root_mean_squared_error: 0.2603 - val_loss: 0.0518 - val_mae: 0.1709 - val_mse: 0.0518 - val_root_mean_squared_error: 0.2277
# Epoch 96/200
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0671 - mae: 0.2126 - mse: 0.0671 - root_mean_squared_error: 0.2599 - val_loss: 0.0523 - val_mae: 0.1713 - val_mse: 0.0523 - val_root_mean_squared_error: 0.2288
# Epoch 97/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0671 - mae: 0.2128 - mse: 0.0671 - root_mean_squared_error: 0.2022 - val_loss: 0.0526 - val_mae: 0.1717 - val_mse: 0.0526 - val_root_mean_squared_error: 0.2294
# Epoch 98/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0671 - mae: 0.2125 - mse: 0.0671 - root_mean_squared_error: 0.2235 - val_loss: 0.0529 - val_mae: 0.1722 - val_mse: 0.0529 - val_root_mean_squared_error: 0.2300
# Epoch 99/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0671 - mae: 0.2126 - mse: 0.0671 - root_mean_squared_error: 0.2410 - val_loss: 0.0534 - val_mae: 0.1728 - val_mse: 0.0534 - val_root_mean_squared_error: 0.2311
# Epoch 100/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0676 - mae: 0.2132 - mse: 0.0676 - root_mean_squared_error: 0.2457 - val_loss: 0.0539 - val_mae: 0.1734 - val_mse: 0.0539 - val_root_mean_squared_error: 0.2321
# Epoch 101/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0681 - mae: 0.2141 - mse: 0.0681 - root_mean_squared_error: 0.2166 - val_loss: 0.0540 - val_mae: 0.1736 - val_mse: 0.0540 - val_root_mean_squared_error: 0.2324
# Epoch 102/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0678 - mae: 0.2133 - mse: 0.0678 - root_mean_squared_error: 0.2207 - val_loss: 0.0541 - val_mae: 0.1736 - val_mse: 0.0541 - val_root_mean_squared_error: 0.2325
# Epoch 103/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0678 - mae: 0.2132 - mse: 0.0678 - root_mean_squared_error: 0.2204 - val_loss: 0.0540 - val_mae: 0.1735 - val_mse: 0.0540 - val_root_mean_squared_error: 0.2323
# Epoch 104/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0678 - mae: 0.2132 - mse: 0.0678 - root_mean_squared_error: 0.2722 - val_loss: 0.0539 - val_mae: 0.1735 - val_mse: 0.0539 - val_root_mean_squared_error: 0.2323
# Epoch 105/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0679 - mae: 0.2133 - mse: 0.0679 - root_mean_squared_error: 0.2249 - val_loss: 0.0537 - val_mae: 0.1732 - val_mse: 0.0537 - val_root_mean_squared_error: 0.2318
# Epoch 106/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0679 - mae: 0.2134 - mse: 0.0679 - root_mean_squared_error: 0.2596 - val_loss: 0.0539 - val_mae: 0.1734 - val_mse: 0.0539 - val_root_mean_squared_error: 0.2321
# Epoch 107/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0678 - mae: 0.2131 - mse: 0.0678 - root_mean_squared_error: 0.2163 - val_loss: 0.0547 - val_mae: 0.1743 - val_mse: 0.0547 - val_root_mean_squared_error: 0.2339
# Epoch 108/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0686 - mae: 0.2135 - mse: 0.0686 - root_mean_squared_error: 0.3056 - val_loss: 0.0549 - val_mae: 0.1745 - val_mse: 0.0549 - val_root_mean_squared_error: 0.2344
# Epoch 109/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0685 - mae: 0.2137 - mse: 0.0685 - root_mean_squared_error: 0.2223 - val_loss: 0.0542 - val_mae: 0.1738 - val_mse: 0.0542 - val_root_mean_squared_error: 0.2328
# Epoch 110/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0680 - mae: 0.2133 - mse: 0.0680 - root_mean_squared_error: 0.2324 - val_loss: 0.0533 - val_mae: 0.1727 - val_mse: 0.0533 - val_root_mean_squared_error: 0.2309
# Epoch 111/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0680 - mae: 0.2138 - mse: 0.0680 - root_mean_squared_error: 0.2586 - val_loss: 0.0528 - val_mae: 0.1720 - val_mse: 0.0528 - val_root_mean_squared_error: 0.2297
# Epoch 112/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0674 - mae: 0.2130 - mse: 0.0674 - root_mean_squared_error: 0.2236 - val_loss: 0.0527 - val_mae: 0.1719 - val_mse: 0.0527 - val_root_mean_squared_error: 0.2296
# Epoch 113/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0674 - mae: 0.2128 - mse: 0.0674 - root_mean_squared_error: 0.2761 - val_loss: 0.0526 - val_mae: 0.1716 - val_mse: 0.0526 - val_root_mean_squared_error: 0.2293
# Epoch 114/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0673 - mae: 0.2126 - mse: 0.0673 - root_mean_squared_error: 0.2422 - val_loss: 0.0524 - val_mae: 0.1713 - val_mse: 0.0524 - val_root_mean_squared_error: 0.2289
# Epoch 115/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0672 - mae: 0.2125 - mse: 0.0672 - root_mean_squared_error: 0.2420 - val_loss: 0.0523 - val_mae: 0.1711 - val_mse: 0.0523 - val_root_mean_squared_error: 0.2286
# Epoch 116/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0672 - mae: 0.2125 - mse: 0.0672 - root_mean_squared_error: 0.2423 - val_loss: 0.0524 - val_mae: 0.1715 - val_mse: 0.0524 - val_root_mean_squared_error: 0.2290
# Epoch 117/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0671 - mae: 0.2126 - mse: 0.0671 - root_mean_squared_error: 0.2105 - val_loss: 0.0528 - val_mae: 0.1720 - val_mse: 0.0528 - val_root_mean_squared_error: 0.2298
# Epoch 118/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0673 - mae: 0.2127 - mse: 0.0673 - root_mean_squared_error: 0.2316 - val_loss: 0.0531 - val_mae: 0.1724 - val_mse: 0.0531 - val_root_mean_squared_error: 0.2304
# Epoch 119/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0673 - mae: 0.2127 - mse: 0.0673 - root_mean_squared_error: 0.2108 - val_loss: 0.0535 - val_mae: 0.1730 - val_mse: 0.0535 - val_root_mean_squared_error: 0.2313
# Epoch 120/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0676 - mae: 0.2131 - mse: 0.0676 - root_mean_squared_error: 0.2115 - val_loss: 0.0540 - val_mae: 0.1736 - val_mse: 0.0540 - val_root_mean_squared_error: 0.2324
# Epoch 121/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0678 - mae: 0.2131 - mse: 0.0678 - root_mean_squared_error: 0.2455 - val_loss: 0.0544 - val_mae: 0.1739 - val_mse: 0.0544 - val_root_mean_squared_error: 0.2332
# Epoch 122/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0681 - mae: 0.2135 - mse: 0.0681 - root_mean_squared_error: 0.2126 - val_loss: 0.0542 - val_mae: 0.1738 - val_mse: 0.0542 - val_root_mean_squared_error: 0.2329
# Epoch 123/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0681 - mae: 0.2137 - mse: 0.0681 - root_mean_squared_error: 0.2491 - val_loss: 0.0539 - val_mae: 0.1734 - val_mse: 0.0539 - val_root_mean_squared_error: 0.2322
# Epoch 124/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0678 - mae: 0.2132 - mse: 0.0678 - root_mean_squared_error: 0.2453 - val_loss: 0.0531 - val_mae: 0.1725 - val_mse: 0.0531 - val_root_mean_squared_error: 0.2305
# Epoch 125/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0675 - mae: 0.2129 - mse: 0.0675 - root_mean_squared_error: 0.2159 - val_loss: 0.0523 - val_mae: 0.1712 - val_mse: 0.0523 - val_root_mean_squared_error: 0.2287
# Epoch 126/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0672 - mae: 0.2125 - mse: 0.0672 - root_mean_squared_error: 0.2334 - val_loss: 0.0520 - val_mae: 0.1706 - val_mse: 0.0520 - val_root_mean_squared_error: 0.2281
# Epoch 127/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0670 - mae: 0.2122 - mse: 0.0670 - root_mean_squared_error: 0.2413 - val_loss: 0.0520 - val_mae: 0.1706 - val_mse: 0.0520 - val_root_mean_squared_error: 0.2279
# Epoch 128/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0670 - mae: 0.2122 - mse: 0.0670 - root_mean_squared_error: 0.2507 - val_loss: 0.0519 - val_mae: 0.1707 - val_mse: 0.0519 - val_root_mean_squared_error: 0.2278
# Epoch 129/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0670 - mae: 0.2120 - mse: 0.0670 - root_mean_squared_error: 0.2379 - val_loss: 0.0517 - val_mae: 0.1712 - val_mse: 0.0517 - val_root_mean_squared_error: 0.2274
# Epoch 130/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0669 - mae: 0.2119 - mse: 0.0669 - root_mean_squared_error: 0.2000 - val_loss: 0.0515 - val_mae: 0.1721 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2270
# Epoch 131/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0672 - mae: 0.2126 - mse: 0.0672 - root_mean_squared_error: 0.2382 - val_loss: 0.0514 - val_mae: 0.1727 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 132/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0671 - mae: 0.2127 - mse: 0.0671 - root_mean_squared_error: 0.2601 - val_loss: 0.0515 - val_mae: 0.1725 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2268
# Epoch 133/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0671 - mae: 0.2126 - mse: 0.0671 - root_mean_squared_error: 0.2428 - val_loss: 0.0516 - val_mae: 0.1718 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2271
# Epoch 134/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0671 - mae: 0.2124 - mse: 0.0671 - root_mean_squared_error: 0.2387 - val_loss: 0.0517 - val_mae: 0.1714 - val_mse: 0.0517 - val_root_mean_squared_error: 0.2273
# Epoch 135/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0671 - mae: 0.2124 - mse: 0.0671 - root_mean_squared_error: 0.2940 - val_loss: 0.0517 - val_mae: 0.1712 - val_mse: 0.0517 - val_root_mean_squared_error: 0.2275
# Epoch 136/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0674 - mae: 0.2131 - mse: 0.0674 - root_mean_squared_error: 0.2421 - val_loss: 0.0519 - val_mae: 0.1706 - val_mse: 0.0519 - val_root_mean_squared_error: 0.2279
# Epoch 137/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0670 - mae: 0.2123 - mse: 0.0670 - root_mean_squared_error: 0.2533 - val_loss: 0.0524 - val_mae: 0.1714 - val_mse: 0.0524 - val_root_mean_squared_error: 0.2289
# Epoch 138/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0671 - mae: 0.2124 - mse: 0.0671 - root_mean_squared_error: 0.2681 - val_loss: 0.0528 - val_mae: 0.1720 - val_mse: 0.0528 - val_root_mean_squared_error: 0.2297
# Epoch 139/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0672 - mae: 0.2126 - mse: 0.0672 - root_mean_squared_error: 0.3061 - val_loss: 0.0529 - val_mae: 0.1722 - val_mse: 0.0529 - val_root_mean_squared_error: 0.2301
# Epoch 140/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0672 - mae: 0.2125 - mse: 0.0672 - root_mean_squared_error: 0.2484 - val_loss: 0.0534 - val_mae: 0.1728 - val_mse: 0.0534 - val_root_mean_squared_error: 0.2310
# Epoch 141/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0674 - mae: 0.2127 - mse: 0.0674 - root_mean_squared_error: 0.3049 - val_loss: 0.0540 - val_mae: 0.1736 - val_mse: 0.0540 - val_root_mean_squared_error: 0.2325
# Epoch 142/200
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0680 - mae: 0.2136 - mse: 0.0680 - root_mean_squared_error: 0.2222 - val_loss: 0.0543 - val_mae: 0.1739 - val_mse: 0.0543 - val_root_mean_squared_error: 0.2331
# Epoch 143/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0679 - mae: 0.2134 - mse: 0.0679 - root_mean_squared_error: 0.2930 - val_loss: 0.0545 - val_mae: 0.1740 - val_mse: 0.0545 - val_root_mean_squared_error: 0.2334
# Epoch 144/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0679 - mae: 0.2133 - mse: 0.0679 - root_mean_squared_error: 0.2177 - val_loss: 0.0543 - val_mae: 0.1739 - val_mse: 0.0543 - val_root_mean_squared_error: 0.2330
# Epoch 145/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0682 - mae: 0.2140 - mse: 0.0682 - root_mean_squared_error: 0.2539 - val_loss: 0.0542 - val_mae: 0.1737 - val_mse: 0.0542 - val_root_mean_squared_error: 0.2328
# Epoch 146/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0678 - mae: 0.2131 - mse: 0.0678 - root_mean_squared_error: 0.2493 - val_loss: 0.0538 - val_mae: 0.1733 - val_mse: 0.0538 - val_root_mean_squared_error: 0.2319
# Epoch 147/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0683 - mae: 0.2141 - mse: 0.0683 - root_mean_squared_error: 0.2805 - val_loss: 0.0533 - val_mae: 0.1727 - val_mse: 0.0533 - val_root_mean_squared_error: 0.2308
# Epoch 148/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0675 - mae: 0.2129 - mse: 0.0675 - root_mean_squared_error: 0.3125 - val_loss: 0.0527 - val_mae: 0.1719 - val_mse: 0.0527 - val_root_mean_squared_error: 0.2296
# Epoch 149/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0672 - mae: 0.2125 - mse: 0.0672 - root_mean_squared_error: 0.1954 - val_loss: 0.0520 - val_mae: 0.1706 - val_mse: 0.0520 - val_root_mean_squared_error: 0.2281
# Epoch 150/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0670 - mae: 0.2121 - mse: 0.0670 - root_mean_squared_error: 0.2481 - val_loss: 0.0516 - val_mae: 0.1717 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2271
# Epoch 151/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0674 - mae: 0.2131 - mse: 0.0674 - root_mean_squared_error: 0.2586 - val_loss: 0.0515 - val_mae: 0.1725 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2268
# Epoch 152/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0672 - mae: 0.2127 - mse: 0.0672 - root_mean_squared_error: 0.2581 - val_loss: 0.0515 - val_mae: 0.1723 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2269
# Epoch 153/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0674 - mae: 0.2131 - mse: 0.0674 - root_mean_squared_error: 0.2331 - val_loss: 0.0517 - val_mae: 0.1713 - val_mse: 0.0517 - val_root_mean_squared_error: 0.2274
# Epoch 154/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0671 - mae: 0.2124 - mse: 0.0671 - root_mean_squared_error: 0.2414 - val_loss: 0.0523 - val_mae: 0.1713 - val_mse: 0.0523 - val_root_mean_squared_error: 0.2288
# Epoch 155/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0672 - mae: 0.2125 - mse: 0.0672 - root_mean_squared_error: 0.2182 - val_loss: 0.0532 - val_mae: 0.1725 - val_mse: 0.0532 - val_root_mean_squared_error: 0.2306
# Epoch 156/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0676 - mae: 0.2130 - mse: 0.0676 - root_mean_squared_error: 0.3024 - val_loss: 0.0537 - val_mae: 0.1732 - val_mse: 0.0537 - val_root_mean_squared_error: 0.2318
# Epoch 157/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0678 - mae: 0.2132 - mse: 0.0678 - root_mean_squared_error: 0.2997 - val_loss: 0.0538 - val_mae: 0.1733 - val_mse: 0.0538 - val_root_mean_squared_error: 0.2319
# Epoch 158/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0678 - mae: 0.2132 - mse: 0.0678 - root_mean_squared_error: 0.2250 - val_loss: 0.0538 - val_mae: 0.1733 - val_mse: 0.0538 - val_root_mean_squared_error: 0.2319
# Epoch 159/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0678 - mae: 0.2132 - mse: 0.0678 - root_mean_squared_error: 0.2204 - val_loss: 0.0539 - val_mae: 0.1734 - val_mse: 0.0539 - val_root_mean_squared_error: 0.2322
# Epoch 160/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0678 - mae: 0.2132 - mse: 0.0678 - root_mean_squared_error: 0.3235 - val_loss: 0.0541 - val_mae: 0.1737 - val_mse: 0.0541 - val_root_mean_squared_error: 0.2326
# Epoch 161/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0680 - mae: 0.2134 - mse: 0.0680 - root_mean_squared_error: 0.2420 - val_loss: 0.0543 - val_mae: 0.1738 - val_mse: 0.0543 - val_root_mean_squared_error: 0.2330
# Epoch 162/200
# 2/2 [==============================] - 0s 88ms/step - loss: 0.0680 - mae: 0.2135 - mse: 0.0680 - root_mean_squared_error: 0.1651 - val_loss: 0.0542 - val_mae: 0.1738 - val_mse: 0.0542 - val_root_mean_squared_error: 0.2328
# Epoch 163/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0679 - mae: 0.2132 - mse: 0.0679 - root_mean_squared_error: 0.2954 - val_loss: 0.0534 - val_mae: 0.1729 - val_mse: 0.0534 - val_root_mean_squared_error: 0.2311
# Epoch 164/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0678 - mae: 0.2134 - mse: 0.0678 - root_mean_squared_error: 0.2336 - val_loss: 0.0524 - val_mae: 0.1714 - val_mse: 0.0524 - val_root_mean_squared_error: 0.2290
# Epoch 165/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0672 - mae: 0.2128 - mse: 0.0672 - root_mean_squared_error: 0.2460 - val_loss: 0.0521 - val_mae: 0.1707 - val_mse: 0.0521 - val_root_mean_squared_error: 0.2282
# Epoch 166/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0670 - mae: 0.2121 - mse: 0.0670 - root_mean_squared_error: 0.1705 - val_loss: 0.0519 - val_mae: 0.1707 - val_mse: 0.0519 - val_root_mean_squared_error: 0.2279
# Epoch 167/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0671 - mae: 0.2124 - mse: 0.0671 - root_mean_squared_error: 0.2378 - val_loss: 0.0519 - val_mae: 0.1706 - val_mse: 0.0519 - val_root_mean_squared_error: 0.2279
# Epoch 168/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0669 - mae: 0.2121 - mse: 0.0669 - root_mean_squared_error: 0.2195 - val_loss: 0.0524 - val_mae: 0.1714 - val_mse: 0.0524 - val_root_mean_squared_error: 0.2290
# Epoch 169/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0671 - mae: 0.2123 - mse: 0.0671 - root_mean_squared_error: 0.2480 - val_loss: 0.0532 - val_mae: 0.1726 - val_mse: 0.0532 - val_root_mean_squared_error: 0.2307
# Epoch 170/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0673 - mae: 0.2127 - mse: 0.0673 - root_mean_squared_error: 0.2273 - val_loss: 0.0542 - val_mae: 0.1737 - val_mse: 0.0542 - val_root_mean_squared_error: 0.2327
# Epoch 171/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0679 - mae: 0.2133 - mse: 0.0679 - root_mean_squared_error: 0.2186 - val_loss: 0.0552 - val_mae: 0.1747 - val_mse: 0.0552 - val_root_mean_squared_error: 0.2349
# Epoch 172/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0685 - mae: 0.2136 - mse: 0.0685 - root_mean_squared_error: 0.2077 - val_loss: 0.0557 - val_mae: 0.1752 - val_mse: 0.0557 - val_root_mean_squared_error: 0.2360
# Epoch 173/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0687 - mae: 0.2139 - mse: 0.0687 - root_mean_squared_error: 0.2638 - val_loss: 0.0563 - val_mae: 0.1756 - val_mse: 0.0563 - val_root_mean_squared_error: 0.2372
# Epoch 174/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0688 - mae: 0.2139 - mse: 0.0688 - root_mean_squared_error: 0.2134 - val_loss: 0.0573 - val_mae: 0.1774 - val_mse: 0.0573 - val_root_mean_squared_error: 0.2394
# Epoch 175/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0702 - mae: 0.2156 - mse: 0.0702 - root_mean_squared_error: 0.2747 - val_loss: 0.0582 - val_mae: 0.1792 - val_mse: 0.0582 - val_root_mean_squared_error: 0.2412
# Epoch 176/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0704 - mae: 0.2158 - mse: 0.0704 - root_mean_squared_error: 0.3119 - val_loss: 0.0580 - val_mae: 0.1788 - val_mse: 0.0580 - val_root_mean_squared_error: 0.2407
# Epoch 177/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0703 - mae: 0.2154 - mse: 0.0703 - root_mean_squared_error: 0.3096 - val_loss: 0.0558 - val_mae: 0.1753 - val_mse: 0.0558 - val_root_mean_squared_error: 0.2363
# Epoch 178/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0686 - mae: 0.2137 - mse: 0.0686 - root_mean_squared_error: 0.3299 - val_loss: 0.0527 - val_mae: 0.1719 - val_mse: 0.0527 - val_root_mean_squared_error: 0.2297
# Epoch 179/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0677 - mae: 0.2137 - mse: 0.0677 - root_mean_squared_error: 0.2335 - val_loss: 0.0514 - val_mae: 0.1732 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 180/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0671 - mae: 0.2131 - mse: 0.0671 - root_mean_squared_error: 0.2921 - val_loss: 0.0522 - val_mae: 0.1763 - val_mse: 0.0522 - val_root_mean_squared_error: 0.2285
# Epoch 181/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0694 - mae: 0.2168 - mse: 0.0694 - root_mean_squared_error: 0.2183 - val_loss: 0.0535 - val_mae: 0.1782 - val_mse: 0.0535 - val_root_mean_squared_error: 0.2313
# Epoch 182/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0705 - mae: 0.2191 - mse: 0.0705 - root_mean_squared_error: 0.2291 - val_loss: 0.0538 - val_mae: 0.1786 - val_mse: 0.0538 - val_root_mean_squared_error: 0.2320
# Epoch 183/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0699 - mae: 0.2181 - mse: 0.0699 - root_mean_squared_error: 0.2643 - val_loss: 0.0530 - val_mae: 0.1776 - val_mse: 0.0530 - val_root_mean_squared_error: 0.2302
# Epoch 184/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0701 - mae: 0.2175 - mse: 0.0701 - root_mean_squared_error: 0.2976 - val_loss: 0.0521 - val_mae: 0.1760 - val_mse: 0.0521 - val_root_mean_squared_error: 0.2282
# Epoch 185/200
# 2/2 [==============================] - 0s 89ms/step - loss: 0.0686 - mae: 0.2149 - mse: 0.0686 - root_mean_squared_error: 0.2464 - val_loss: 0.0515 - val_mae: 0.1743 - val_mse: 0.0515 - val_root_mean_squared_error: 0.2270
# Epoch 186/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0675 - mae: 0.2131 - mse: 0.0675 - root_mean_squared_error: 0.2955 - val_loss: 0.0516 - val_mae: 0.1718 - val_mse: 0.0516 - val_root_mean_squared_error: 0.2271
# Epoch 187/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0672 - mae: 0.2125 - mse: 0.0672 - root_mean_squared_error: 0.2299 - val_loss: 0.0529 - val_mae: 0.1722 - val_mse: 0.0529 - val_root_mean_squared_error: 0.2300
# Epoch 188/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0678 - mae: 0.2133 - mse: 0.0678 - root_mean_squared_error: 0.2996 - val_loss: 0.0552 - val_mae: 0.1747 - val_mse: 0.0552 - val_root_mean_squared_error: 0.2350
# Epoch 189/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0686 - mae: 0.2140 - mse: 0.0686 - root_mean_squared_error: 0.2393 - val_loss: 0.0570 - val_mae: 0.1766 - val_mse: 0.0570 - val_root_mean_squared_error: 0.2387
# Epoch 190/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0696 - mae: 0.2153 - mse: 0.0696 - root_mean_squared_error: 0.2215 - val_loss: 0.0578 - val_mae: 0.1784 - val_mse: 0.0578 - val_root_mean_squared_error: 0.2404
# Epoch 191/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0697 - mae: 0.2150 - mse: 0.0697 - root_mean_squared_error: 0.2204 - val_loss: 0.0584 - val_mae: 0.1797 - val_mse: 0.0584 - val_root_mean_squared_error: 0.2417
# Epoch 192/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0700 - mae: 0.2151 - mse: 0.0700 - root_mean_squared_error: 0.2216 - val_loss: 0.0588 - val_mae: 0.1804 - val_mse: 0.0588 - val_root_mean_squared_error: 0.2425
# Epoch 193/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0695 - mae: 0.2146 - mse: 0.0695 - root_mean_squared_error: 0.2382 - val_loss: 0.0587 - val_mae: 0.1802 - val_mse: 0.0587 - val_root_mean_squared_error: 0.2422
# Epoch 194/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0704 - mae: 0.2155 - mse: 0.0704 - root_mean_squared_error: 0.2723 - val_loss: 0.0576 - val_mae: 0.1780 - val_mse: 0.0576 - val_root_mean_squared_error: 0.2400
# Epoch 195/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0696 - mae: 0.2148 - mse: 0.0696 - root_mean_squared_error: 0.2387 - val_loss: 0.0557 - val_mae: 0.1752 - val_mse: 0.0557 - val_root_mean_squared_error: 0.2361
# Epoch 196/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0688 - mae: 0.2143 - mse: 0.0688 - root_mean_squared_error: 0.2509 - val_loss: 0.0540 - val_mae: 0.1736 - val_mse: 0.0540 - val_root_mean_squared_error: 0.2325
# Epoch 197/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0677 - mae: 0.2130 - mse: 0.0677 - root_mean_squared_error: 0.3236 - val_loss: 0.0526 - val_mae: 0.1718 - val_mse: 0.0526 - val_root_mean_squared_error: 0.2294
# Epoch 198/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0673 - mae: 0.2126 - mse: 0.0673 - root_mean_squared_error: 0.2278 - val_loss: 0.0517 - val_mae: 0.1714 - val_mse: 0.0517 - val_root_mean_squared_error: 0.2273
# Epoch 199/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0671 - mae: 0.2126 - mse: 0.0671 - root_mean_squared_error: 0.2029 - val_loss: 0.0514 - val_mae: 0.1728 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 200/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0674 - mae: 0.2142 - mse: 0.0674 - root_mean_squared_error: 0.1917 - val_loss: 0.0514 - val_mae: 0.1736 - val_mse: 0.0514 - val_root_mean_squared_error: 0.2268

# %% [markdown]
#     Evaluate the Models

# %%
# Evaluate on validation set
val_metrics_manul = manul_model.evaluate(val_data_inputs, val_data_targets, return_dict=True)
val_metrics_keras = keras_model.evaluate(val_data_inputs, val_data_targets, return_dict=True)

# Evaluate on test set
test_metrics_manul = manul_model.evaluate(test_data_inputs, test_data_targets, return_dict=True)
test_metrics_keras = keras_model.evaluate(test_data_inputs, test_data_targets, return_dict=True)

# Extract individual metrics
val_loss_manul, val_mae_manul, val_mse_manul, val_rmse_manul = val_metrics_manul['loss'], val_metrics_manul['mae'], val_metrics_manul['mse'], val_metrics_manul['root_mean_squared_error']
test_loss_manul, test_mae_manul, test_mse_manul, test_rmse_manul = test_metrics_manul['loss'], test_metrics_manul['mae'], test_metrics_manul['mse'], test_metrics_manul['root_mean_squared_error']

val_loss_keras, val_mae_keras, val_mse_keras, val_rmse_keras = val_metrics_keras['loss'], val_metrics_keras['mae'], val_metrics_keras['mse'], val_metrics_keras['root_mean_squared_error']
test_loss_keras, test_mae_keras, test_mse_keras, test_rmse_keras = test_metrics_keras['loss'], test_metrics_keras['mae'], test_metrics_keras['mse'], test_metrics_keras['root_mean_squared_error']

print('\n\nManual Transformer:\n-------------------')
print(f'Validation Loss: {val_loss_manul}, Validation MSE: {val_mse_manul}, Validation MAE: {val_mae_manul}, Validation RMSE: {val_rmse_manul}')
print(f'Test Loss: {test_loss_manul}, Test MSE: {test_mse_manul}, Test MAE: {test_mae_manul}, Test RMSE: {test_rmse_manul}')

print('\nKeras Transformer:\n------------------')
print(f'Validation Loss: {val_loss_keras}, Validation MSE: {val_mse_keras}, Validation MAE: {val_mae_keras}, Validation RMSE: {val_rmse_keras}')
print(f'Test Loss: {test_loss_keras}, Test MSE: {test_mse_keras}, Test MAE: {test_mae_keras}, Test RMSE: {test_rmse_keras}')
# Out:
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0550 - mae: 0.1745 - mse: 0.0550 - root_mean_squared_error: 0.2346
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0514 - mae: 0.1736 - mse: 0.0514 - root_mean_squared_error: 0.2268
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0297 - mae: 0.1615 - mse: 0.0297 - root_mean_squared_error: 0.1724
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0306 - mae: 0.1615 - mse: 0.0306 - root_mean_squared_error: 0.1749
#
#
# Manual Transformer:
# -------------------
# Validation Loss: 0.05501659959554672, Validation MSE: 0.05501659959554672, Validation MAE: 0.1745423674583435, Validation RMSE: 0.234556183218956
# Test Loss: 0.0297355018556118, Test MSE: 0.0297355018556118, Test MAE: 0.16150200366973877, Test RMSE: 0.17243985831737518
#
# Keras Transformer:
# ------------------
# Validation Loss: 0.051432158797979355, Validation MSE: 0.051432158797979355, Validation MAE: 0.17358893156051636, Validation RMSE: 0.22678658366203308
# Test Loss: 0.030582088977098465, Test MSE: 0.030582088977098465, Test MAE: 0.16150200366973877, Test RMSE: 0.1748773604631424

# %%
# Assuming manul_model.predict returns the predictions
val_predictions_manul = manul_model.predict(val_data_inputs)
test_predictions_manul = manul_model.predict(test_data_inputs)

# Assuming keras_model.predict returns the predictions
val_predictions_keras = keras_model.predict(val_data_inputs)
test_predictions_keras  = keras_model.predict(test_data_inputs)

# Calculate MAE and RMSE for validation set
val_mae_manul = np.mean(np.abs(val_data_targets - val_predictions_manul))
val_rmse_manul = np.sqrt(np.mean(np.square(val_data_targets - val_predictions_manul)))

val_mae_keras  = np.mean(np.abs(val_data_targets - val_predictions_keras ))
val_rmse_keras  = np.sqrt(np.mean(np.square(val_data_targets - val_predictions_keras )))

# Calculate MAE and RMSE for test set
test_mae_manul = np.mean(np.abs(test_data_targets - test_predictions_manul))
test_rmse_manul = np.sqrt(np.mean(np.square(test_data_targets - test_predictions_manul)))

test_mae_keras  = np.mean(np.abs(test_data_targets - test_predictions_keras ))
test_rmse_keras  = np.sqrt(np.mean(np.square(test_data_targets - test_predictions_keras )))


print('\n\nManual Transformer:\n-------------------')
print(f'Validation MAE: {val_mae_manul}')
print(f'Validation RMSE: {val_rmse_manul}')
print(f'\nTest MAE: {test_mae_manul}')
print(f'Test RMSE: {test_rmse_manul}')
print('\n==============================')
print('\nKeras Transformer:\n------------------')
print(f'Validation MAE: {val_mae_keras }')
print(f'Validation RMSE: {val_rmse_keras }')
print(f'\nTest MAE: {test_mae_keras }')
print(f'Test RMSE: {test_rmse_keras }')
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000221FFCCDDC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 721ms/step
# 1/1 [==============================] - 0s 24ms/step
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000221FFE62040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 26ms/step
#
#
# Manual Transformer:
# -------------------
# Validation MAE: 0.1745423674583435
# Validation RMSE: 0.234556183218956
#
# Test MAE: 0.16150199871259407
# Test RMSE: 0.17243983993340525
#
# ==============================
#
# Keras Transformer:
# ------------------
# Validation MAE: 0.17358893156051636
# Validation RMSE: 0.22678659856319427
#
# Test MAE: 0.16150199871259407
# Test RMSE: 0.17487734073030523
